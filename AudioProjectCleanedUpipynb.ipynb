# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install jams
# Out:
# Mounted at /content/drive
# Collecting jams
#   Downloading jams-0.3.4.tar.gz (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 kB 800.7 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from jams) (2.1.4)
# Collecting sortedcontainers>=2.0.0 (from jams)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: jsonschema>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from jams) (4.23.0)
# Requirement already satisfied: numpy>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from jams) (1.26.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from jams) (1.16.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from jams) (5.1.1)
# Collecting mir_eval>=0.5 (from jams)
#   Downloading mir_eval-0.7.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.7/90.7 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0.0->jams) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0.0->jams) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0.0->jams) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0.0->jams) (0.20.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from mir_eval>=0.5->jams) (1.13.1)
# Collecting future (from mir_eval>=0.5->jams)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->jams) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->jams) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->jams) (2024.1)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 5.5 MB/s eta 0:00:00
# Building wheels for collected packages: jams, mir_eval
#   Building wheel for jams (setup.py) ... done
#   Created wheel for jams: filename=jams-0.3.4-py3-none-any.whl size=64901 sha256=f653407fcf6f66ed17e28d4fd5ea7ee676932013f0f21f9694d38aac650c1a1c
#   Stored in directory: /root/.cache/pip/wheels/28/9a/f7/fb386b6bc5a75a3ef198a50e98b221e94a381472332b65cf24
#   Building wheel for mir_eval (setup.py) ... done
#   Created wheel for mir_eval: filename=mir_eval-0.7-py3-none-any.whl size=100699 sha256=86e5642f26ebb508a36d9d9f3ff9dc479789e30e22c050f1dd7de49016616b28
#   Stored in directory: /root/.cache/pip/wheels/3e/2f/0d/dda9c4c77a170e21356b6afa2f7d9bb078338634ba05d94e3f
# Successfully built jams mir_eval
# Installing collected packages: sortedcontainers, future, mir_eval, jams
# Successfully installed future-1.0.0 jams-0.3.4 mir_eval-0.7 sortedcontainers-2.4.0

# %%
#@title Detecting Frets from JAMS
import os
import jams
import numpy as np

def generate_tabs_from_jams(dataset_dir):
    # Define the directory where JAMS files are stored
    annotation_dir = os.path.join(dataset_dir, "annotation")

    # Create the Tabs directory if it doesn't exist
    tabs_dir = os.path.join(dataset_dir, "Tabs")
    os.makedirs(tabs_dir, exist_ok=True)

    # Iterate through all JAMS files in the annotation directory
    for filename in os.listdir(annotation_dir):
        if filename.endswith(".jams"):
            jams_file_path = os.path.join(annotation_dir, filename)
            generate_tab_for_file(jams_file_path, tabs_dir)

def generate_tab_for_file(jams_file_path, tabs_dir):
    # Load the JAMS file
    jam = jams.load(jams_file_path)

    # Extract tablature information from JAMS annotations
    tab_data = process_jam_to_tab(jam)

    # Save or print tab data
    print_tab_data(tab_data, jams_file_path, tabs_dir)

def process_jam_to_tab(jam):
    string_midi_pitches = [40, 45, 50, 55, 59, 64]  # E2, A2, D3, G3, B3, E4
    tab_data = {1: [], 2: [], 3: [], 4: [], 5: [], 6: []}  # Initialize strings

    for anno in jam.annotations:
        if anno.namespace == 'note_midi':
            for note in anno.data:
                midi_pitch = note.value
                string_number, fret_number = find_string_and_fret(midi_pitch, string_midi_pitches)
                if string_number is not None and fret_number is not None:
                    rounded_fret = round(fret_number)
                    print(f"Found fret number: {rounded_fret} on string {string_number} at time {note.time:.2f}")
                    tab_data[string_number].append((note.time, rounded_fret))

    # Sort each string's notes by time
    for string_number in tab_data:
        tab_data[string_number].sort(key=lambda x: x[0])

    return tab_data

def find_string_and_fret(midi_pitch, string_midi_pitches):
    for string_number, open_string_pitch in enumerate(string_midi_pitches):
        if midi_pitch >= open_string_pitch and midi_pitch <= open_string_pitch + 19:
            fret_number = midi_pitch - open_string_pitch
            return string_number + 1, fret_number  # Adding 1 to match string numbering (1-6)
    return None, None

def format_tab_line(tab_line):
    formatted_line = []
    last_char = ""
    i = 0

    while i < len(tab_line):
        char = tab_line[i]

        # Determine the length of the current "fret" (could be 1 or 2 digits)
        if char.isdigit():
            fret_len = 1
            if i + 1 < len(tab_line) and tab_line[i + 1].isdigit():
                fret_len = 2

            # If fret_len is 2 or greater, add the dash after the next character
            if fret_len >= 2:
                formatted_line.append(char)
                i += 1  # Skip the next character to account for the second digit
                if i < len(tab_line):
                    formatted_line.append(tab_line[i])
                    if i + 1 < len(tab_line) and tab_line[i + 1] != '|':
                        formatted_line.append('-')
            else:
                formatted_line.append(char)
                if i + 1 < len(tab_line) and tab_line[i + 1] != '|':
                    formatted_line.append('-')
        else:
            formatted_line.append(char)

        last_char = char
        i += 1

    return ''.join(formatted_line)

#Currently unused due to complexity of changing time signatures to determine bar lengths
def add_bar_lines(tab_representation, bar_interval=25):
    max_len = max(len(line) for line in tab_representation.values())

    # Convert each string's representation from string to list for modification
    padded_tab_representation = {k: list(v) for k, v in tab_representation.items()}

    for string_number, line in padded_tab_representation.items():
        current_len = len(line)
        if current_len < max_len:
            line.extend(['-'] * (max_len - current_len))

    # Add bar lines at regular intervals, ensuring dashes don't touch the fret numbers
    bar_lines_added = {1: [], 2: [], 3: [], 4: [], 5: [], 6: []}
    for string_number, line in padded_tab_representation.items():
        bar_start = 0
        while bar_start < len(line):
            bar_end = min(bar_start + bar_interval, len(line))
            bar_segment = line[bar_start:bar_end]

            # Ensure there's always a dash between a fret number and a bar "|"
            if bar_end < len(line):
                if bar_segment[-1].isdigit():
                    bar_segment.append('-')
                bar_segment.append('|')
            bar_lines_added[string_number].extend(bar_segment)
            bar_start += bar_interval

    # Convert back to string format
    for string_number in bar_lines_added:
        tab_representation[string_number] = ''.join(bar_lines_added[string_number])

def print_tab_data(tab_data, jams_file_path, tabs_dir):
    max_time = max(max(notes, key=lambda x: x[0])[0] if notes else 0 for notes in tab_data.values())
    tab_length = int(max_time * 10)  # Assume each 0.1s step corresponds to one position in the tab

    # Initialize strings with dashes
    tab_representation = {1: ['-'] * tab_length, 2: ['-'] * tab_length, 3: ['-'] * tab_length,
                          4: ['-'] * tab_length, 5: ['-'] * tab_length, 6: ['-'] * tab_length}

    # Place frets on the appropriate positions
    for string_number, notes in tab_data.items():
        for time, fret in notes:
            position = int(time * 10)
            fret_str = str(fret)
            fret_len = len(fret_str)

            if position + fret_len <= len(tab_representation[string_number]):
                tab_representation[string_number][position:position + fret_len] = list(fret_str)

                # Ensure dash before and after fret number
                if position + fret_len < len(tab_representation[string_number]):
                    tab_representation[string_number][position + fret_len] = '-'
                if position > 0 and not tab_representation[string_number][position - 1].isdigit():
                    tab_representation[string_number][position - 1] = '-'

    # Format each tab line to ensure spacing between numbers
    for string_number in tab_representation:
        tab_representation[string_number] = format_tab_line(tab_representation[string_number])

    # Add bar lines at regular intervals
    add_bar_lines(tab_representation, bar_interval=25)

    # Prepare the string labels
    string_labels = {1: "e|", 2: "B|", 3: "G|", 4: "D|", 5: "A|", 6: "E|"}

    # Save the tab data to a file in the Tabs directory
    base_filename = os.path.basename(jams_file_path).replace(".jams", ".txt")
    tab_filename = os.path.join(tabs_dir, base_filename)

    with open(tab_filename, 'w') as f:
        for string_number in range(6, 0, -1):  # Print from high E (string 1) to low E (string 6)
            f.write(f"{string_labels[string_number]}{tab_representation[string_number]}\n")

# Path to your dataset directory
dataset_dir = '/content/drive/MyDrive/Summer2024Research/GuitarSet'

# Call the function to process all JAMS files
generate_tabs_from_jams(dataset_dir)
# Out:
# Streaming output truncated to the last 5000 lines.
# Found fret number: 16 on string 3 at time 0.80
# Found fret number: 19 on string 2 at time 1.61
# Found fret number: 17 on string 2 at time 3.23
# Found fret number: 16 on string 2 at time 4.03
# Found fret number: 16 on string 4 at time 6.92
# Found fret number: 14 on string 4 at time 7.23
# Found fret number: 18 on string 3 at time 7.54
# Found fret number: 16 on string 4 at time 8.12
# Found fret number: 19 on string 3 at time 8.23
# Found fret number: 18 on string 3 at time 8.50
# Found fret number: 18 on string 3 at time 17.70
# Found fret number: 15 on string 5 at time 0.48
# Found fret number: 19 on string 4 at time 1.02
# Found fret number: 18 on string 4 at time 1.33
# Found fret number: 18 on string 4 at time 1.80
# Found fret number: 16 on string 4 at time 3.04
# Found fret number: 16 on string 4 at time 3.42
# Found fret number: 14 on string 4 at time 3.72
# Found fret number: 14 on string 4 at time 4.31
# Found fret number: 18 on string 3 at time 5.58
# Found fret number: 19 on string 3 at time 5.73
# Found fret number: 16 on string 4 at time 5.91
# Found fret number: 19 on string 4 at time 6.15
# Found fret number: 17 on string 4 at time 6.38
# Found fret number: 18 on string 4 at time 6.60
# Found fret number: 7 on string 1 at time 0.01
# Found fret number: 7 on string 1 at time 0.30
# Found fret number: 7 on string 1 at time 0.62
# Found fret number: 7 on string 1 at time 0.92
# Found fret number: 5 on string 1 at time 2.88
# Found fret number: 5 on string 1 at time 3.19
# Found fret number: 5 on string 1 at time 3.52
# Found fret number: 4 on string 1 at time 5.11
# Found fret number: 4 on string 1 at time 5.75
# Found fret number: 0 on string 1 at time 7.35
# Found fret number: 2 on string 1 at time 7.68
# Found fret number: 2 on string 1 at time 8.29
# Found fret number: 2 on string 1 at time 8.59
# Found fret number: 2 on string 1 at time 8.93
# Found fret number: 2 on string 1 at time 9.56
# Found fret number: 2 on string 1 at time 9.64
# Found fret number: 2 on string 1 at time 9.86
# Found fret number: 7 on string 1 at time 10.18
# Found fret number: 7 on string 1 at time 11.20
# Found fret number: 5 on string 1 at time 13.12
# Found fret number: 5 on string 1 at time 13.30
# Found fret number: 5 on string 1 at time 13.78
# Found fret number: 4 on string 1 at time 15.33
# Found fret number: 4 on string 1 at time 15.68
# Found fret number: 4 on string 1 at time 16.02
# Found fret number: 2 on string 1 at time 16.42
# Found fret number: 2 on string 1 at time 17.96
# Found fret number: 2 on string 1 at time 18.59
# Found fret number: 2 on string 1 at time 19.20
# Found fret number: 2 on string 1 at time 19.84
# Found fret number: 12 on string 1 at time 1.25
# Found fret number: 12 on string 1 at time 1.60
# Found fret number: 12 on string 1 at time 1.92
# Found fret number: 12 on string 1 at time 2.24
# Found fret number: 10 on string 1 at time 3.84
# Found fret number: 10 on string 1 at time 4.17
# Found fret number: 10 on string 1 at time 4.49
# Found fret number: 10 on string 1 at time 4.80
# Found fret number: 9 on string 1 at time 6.38
# Found fret number: 9 on string 1 at time 6.72
# Found fret number: 9 on string 1 at time 7.05
# Found fret number: 9 on string 1 at time 7.36
# Found fret number: 12 on string 1 at time 11.51
# Found fret number: 12 on string 1 at time 11.85
# Found fret number: 12 on string 1 at time 12.17
# Found fret number: 12 on string 1 at time 12.49
# Found fret number: 10 on string 1 at time 12.80
# Found fret number: 10 on string 1 at time 14.31
# Found fret number: 10 on string 1 at time 14.62
# Found fret number: 10 on string 1 at time 15.04
# Found fret number: 17 on string 1 at time 0.00
# Found fret number: 17 on string 1 at time 0.30
# Found fret number: 17 on string 1 at time 0.64
# Found fret number: 17 on string 1 at time 0.94
# Found fret number: 16 on string 1 at time 1.25
# Found fret number: 16 on string 1 at time 1.60
# Found fret number: 16 on string 1 at time 1.92
# Found fret number: 16 on string 1 at time 2.24
# Found fret number: 15 on string 1 at time 2.56
# Found fret number: 15 on string 1 at time 2.89
# Found fret number: 15 on string 1 at time 3.21
# Found fret number: 15 on string 1 at time 3.53
# Found fret number: 14 on string 1 at time 3.85
# Found fret number: 14 on string 1 at time 4.18
# Found fret number: 14 on string 1 at time 4.50
# Found fret number: 14 on string 1 at time 4.81
# Found fret number: 14 on string 1 at time 5.31
# Found fret number: 14 on string 1 at time 5.76
# Found fret number: 14 on string 1 at time 6.07
# Found fret number: 13 on string 1 at time 6.38
# Found fret number: 13 on string 1 at time 6.72
# Found fret number: 13 on string 1 at time 7.05
# Found fret number: 13 on string 1 at time 7.36
# Found fret number: 12 on string 1 at time 7.87
# Found fret number: 12 on string 1 at time 8.20
# Found fret number: 12 on string 1 at time 8.30
# Found fret number: 12 on string 1 at time 8.62
# Found fret number: 11 on string 1 at time 8.85
# Found fret number: 12 on string 1 at time 8.96
# Found fret number: 12 on string 1 at time 9.14
# Found fret number: 12 on string 1 at time 9.47
# Found fret number: 12 on string 1 at time 9.59
# Found fret number: 12 on string 1 at time 9.91
# Found fret number: 17 on string 1 at time 10.57
# Found fret number: 17 on string 1 at time 10.89
# Found fret number: 17 on string 1 at time 11.22
# Found fret number: 16 on string 1 at time 11.52
# Found fret number: 16 on string 1 at time 11.87
# Found fret number: 16 on string 1 at time 12.18
# Found fret number: 16 on string 1 at time 12.50
# Found fret number: 15 on string 1 at time 13.14
# Found fret number: 15 on string 1 at time 13.47
# Found fret number: 15 on string 1 at time 13.79
# Found fret number: 17 on string 1 at time 14.31
# Found fret number: 17 on string 1 at time 14.62
# Found fret number: 17 on string 1 at time 15.05
# Found fret number: 14 on string 1 at time 15.36
# Found fret number: 14 on string 1 at time 15.70
# Found fret number: 14 on string 1 at time 16.02
# Found fret number: 14 on string 1 at time 16.35
# Found fret number: 14 on string 1 at time 16.66
# Found fret number: 14 on string 1 at time 17.00
# Found fret number: 14 on string 1 at time 17.32
# Found fret number: 14 on string 1 at time 17.63
# Found fret number: 11 on string 1 at time 18.16
# Found fret number: 10 on string 1 at time 18.50
# Found fret number: 11 on string 1 at time 18.79
# Found fret number: 10 on string 1 at time 19.10
# Found fret number: 11 on string 1 at time 19.42
# Found fret number: 10 on string 1 at time 19.73
# Found fret number: 11 on string 1 at time 19.85
# Found fret number: 17 on string 2 at time 0.01
# Found fret number: 17 on string 2 at time 0.31
# Found fret number: 17 on string 2 at time 0.64
# Found fret number: 17 on string 2 at time 0.95
# Found fret number: 16 on string 2 at time 1.16
# Found fret number: 17 on string 2 at time 1.25
# Found fret number: 17 on string 2 at time 1.60
# Found fret number: 17 on string 2 at time 1.93
# Found fret number: 17 on string 2 at time 2.25
# Found fret number: 15 on string 2 at time 2.46
# Found fret number: 16 on string 2 at time 2.57
# Found fret number: 16 on string 2 at time 2.90
# Found fret number: 16 on string 2 at time 3.22
# Found fret number: 16 on string 2 at time 3.54
# Found fret number: 16 on string 2 at time 3.70
# Found fret number: 16 on string 2 at time 3.85
# Found fret number: 16 on string 2 at time 4.19
# Found fret number: 16 on string 2 at time 4.51
# Found fret number: 16 on string 2 at time 4.82
# Found fret number: 15 on string 1 at time 5.02
# Found fret number: 19 on string 1 at time 5.32
# Found fret number: 14 on string 2 at time 5.77
# Found fret number: 14 on string 2 at time 6.08
# Found fret number: 14 on string 2 at time 6.30
# Found fret number: 14 on string 2 at time 6.40
# Found fret number: 14 on string 2 at time 6.73
# Found fret number: 14 on string 2 at time 7.06
# Found fret number: 14 on string 2 at time 7.37
# Found fret number: 15 on string 1 at time 7.57
# Found fret number: 17 on string 1 at time 7.88
# Found fret number: 17 on string 1 at time 8.18
# Found fret number: 17 on string 1 at time 8.31
# Found fret number: 17 on string 1 at time 8.63
# Found fret number: 18 on string 1 at time 9.14
# Found fret number: 17 on string 1 at time 9.46
# Found fret number: 18 on string 1 at time 9.60
# Found fret number: 18 on string 1 at time 9.91
# Found fret number: 17 on string 2 at time 10.25
# Found fret number: 17 on string 2 at time 10.58
# Found fret number: 17 on string 2 at time 10.90
# Found fret number: 17 on string 2 at time 11.22
# Found fret number: 16 on string 2 at time 11.37
# Found fret number: 17 on string 2 at time 11.52
# Found fret number: 17 on string 2 at time 11.87
# Found fret number: 17 on string 2 at time 12.19
# Found fret number: 17 on string 2 at time 12.51
# Found fret number: 16 on string 2 at time 12.81
# Found fret number: 16 on string 2 at time 12.91
# Found fret number: 16 on string 2 at time 13.15
# Found fret number: 16 on string 2 at time 13.48
# Found fret number: 16 on string 2 at time 13.80
# Found fret number: 16 on string 2 at time 14.32
# Found fret number: 16 on string 2 at time 14.97
# Found fret number: 16 on string 2 at time 15.05
# Found fret number: 14 on string 2 at time 15.70
# Found fret number: 14 on string 2 at time 16.04
# Found fret number: 14 on string 2 at time 16.36
# Found fret number: 14 on string 2 at time 16.58
# Found fret number: 14 on string 2 at time 16.67
# Found fret number: 14 on string 2 at time 17.01
# Found fret number: 14 on string 2 at time 17.33
# Found fret number: 14 on string 2 at time 17.64
# Found fret number: 15 on string 1 at time 17.85
# Found fret number: 17 on string 1 at time 17.98
# Found fret number: 17 on string 1 at time 18.16
# Found fret number: 17 on string 1 at time 18.49
# Found fret number: 17 on string 1 at time 18.80
# Found fret number: 16 on string 1 at time 19.08
# Found fret number: 17 on string 1 at time 19.42
# Found fret number: 16 on string 1 at time 19.70
# Found fret number: 17 on string 1 at time 19.85
# Found fret number: 16 on string 3 at time 0.00
# Found fret number: 16 on string 3 at time 0.32
# Found fret number: 16 on string 3 at time 0.65
# Found fret number: 16 on string 3 at time 0.95
# Found fret number: 16 on string 3 at time 1.16
# Found fret number: 16 on string 3 at time 1.26
# Found fret number: 16 on string 3 at time 1.61
# Found fret number: 16 on string 3 at time 1.94
# Found fret number: 16 on string 3 at time 2.26
# Found fret number: 14 on string 3 at time 2.91
# Found fret number: 14 on string 3 at time 3.22
# Found fret number: 14 on string 3 at time 3.55
# Found fret number: 19 on string 2 at time 3.74
# Found fret number: 14 on string 3 at time 3.86
# Found fret number: 19 on string 2 at time 4.19
# Found fret number: 19 on string 2 at time 4.51
# Found fret number: 19 on string 2 at time 4.82
# Found fret number: 19 on string 1 at time 5.01
# Found fret number: 17 on string 2 at time 5.32
# Found fret number: 17 on string 2 at time 5.77
# Found fret number: 17 on string 2 at time 6.08
# Found fret number: 19 on string 1 at time 6.29
# Found fret number: 17 on string 2 at time 6.40
# Found fret number: 17 on string 2 at time 6.74
# Found fret number: 17 on string 2 at time 7.07
# Found fret number: 17 on string 2 at time 7.38
# Found fret number: 19 on string 1 at time 7.57
# Found fret number: 16 on string 2 at time 7.88
# Found fret number: 16 on string 2 at time 8.32
# Found fret number: 16 on string 2 at time 8.63
# Found fret number: 17 on string 2 at time 9.15
# Found fret number: 17 on string 2 at time 9.45
# Found fret number: 17 on string 2 at time 9.92
# Found fret number: 16 on string 3 at time 10.15
# Found fret number: 16 on string 3 at time 10.27
# Found fret number: 16 on string 3 at time 10.59
# Found fret number: 16 on string 3 at time 10.91
# Found fret number: 16 on string 3 at time 11.23
# Found fret number: 16 on string 3 at time 11.43
# Found fret number: 16 on string 3 at time 11.53
# Found fret number: 16 on string 3 at time 11.87
# Found fret number: 16 on string 3 at time 12.19
# Found fret number: 16 on string 3 at time 12.51
# Found fret number: 14 on string 3 at time 13.15
# Found fret number: 19 on string 2 at time 13.48
# Found fret number: 19 on string 2 at time 13.80
# Found fret number: 19 on string 1 at time 13.99
# Found fret number: 16 on string 3 at time 14.32
# Found fret number: 16 on string 3 at time 14.63
# Found fret number: 16 on string 3 at time 14.97
# Found fret number: 16 on string 3 at time 15.06
# Found fret number: 19 on string 1 at time 15.26
# Found fret number: 17 on string 2 at time 15.70
# Found fret number: 17 on string 2 at time 16.04
# Found fret number: 17 on string 2 at time 16.36
# Found fret number: 19 on string 1 at time 16.56
# Found fret number: 17 on string 2 at time 16.67
# Found fret number: 17 on string 2 at time 17.01
# Found fret number: 17 on string 2 at time 17.33
# Found fret number: 17 on string 2 at time 17.65
# Found fret number: 19 on string 1 at time 17.84
# Found fret number: 16 on string 2 at time 18.17
# Found fret number: 16 on string 2 at time 18.80
# Found fret number: 16 on string 2 at time 19.43
# Found fret number: 16 on string 2 at time 19.86
# Found fret number: 6 on string 1 at time 2.17
# Found fret number: 6 on string 1 at time 2.62
# Found fret number: 8 on string 1 at time 3.49
# Found fret number: 8 on string 1 at time 3.94
# Found fret number: 8 on string 1 at time 4.37
# Found fret number: 8 on string 1 at time 4.81
# Found fret number: 3 on string 1 at time 5.25
# Found fret number: 3 on string 1 at time 5.67
# Found fret number: 3 on string 1 at time 6.09
# Found fret number: 3 on string 1 at time 6.54
# Found fret number: 4 on string 1 at time 6.94
# Found fret number: 4 on string 1 at time 7.87
# Found fret number: 4 on string 1 at time 8.30
# Found fret number: 4 on string 1 at time 10.50
# Found fret number: 4 on string 1 at time 10.93
# Found fret number: 4 on string 1 at time 11.37
# Found fret number: 4 on string 1 at time 11.80
# Found fret number: 6 on string 1 at time 12.24
# Found fret number: 6 on string 1 at time 12.52
# Found fret number: 6 on string 1 at time 12.94
# Found fret number: 6 on string 1 at time 13.10
# Found fret number: 6 on string 1 at time 13.54
# Found fret number: 6 on string 1 at time 15.73
# Found fret number: 6 on string 1 at time 16.46
# Found fret number: 6 on string 1 at time 16.56
# Found fret number: 6 on string 1 at time 17.01
# Found fret number: 8 on string 1 at time 17.47
# Found fret number: 8 on string 1 at time 17.90
# Found fret number: 3 on string 1 at time 19.23
# Found fret number: 3 on string 1 at time 20.52
# Found fret number: 4 on string 1 at time 20.96
# Found fret number: 4 on string 1 at time 21.87
# Found fret number: 4 on string 1 at time 22.15
# Found fret number: 4 on string 1 at time 24.49
# Found fret number: 4 on string 1 at time 24.94
# Found fret number: 4 on string 1 at time 25.40
# Found fret number: 4 on string 1 at time 25.82
# Found fret number: 5 on string 1 at time 26.26
# Found fret number: 6 on string 1 at time 26.54
# Found fret number: 6 on string 1 at time 26.98
# Found fret number: 11 on string 1 at time 0.00
# Found fret number: 11 on string 1 at time 0.42
# Found fret number: 11 on string 1 at time 0.84
# Found fret number: 11 on string 1 at time 1.30
# Found fret number: 10 on string 1 at time 1.73
# Found fret number: 11 on string 1 at time 8.73
# Found fret number: 11 on string 1 at time 9.16
# Found fret number: 11 on string 1 at time 9.62
# Found fret number: 11 on string 1 at time 10.05
# Found fret number: 11 on string 1 at time 13.98
# Found fret number: 11 on string 1 at time 14.42
# Found fret number: 11 on string 1 at time 22.74
# Found fret number: 11 on string 1 at time 23.04
# Found fret number: 11 on string 1 at time 23.48
# Found fret number: 11 on string 1 at time 24.04
# Found fret number: 18 on string 1 at time 0.00
# Found fret number: 18 on string 1 at time 0.43
# Found fret number: 18 on string 1 at time 0.85
# Found fret number: 18 on string 1 at time 1.30
# Found fret number: 16 on string 1 at time 1.74
# Found fret number: 17 on string 1 at time 2.18
# Found fret number: 17 on string 1 at time 2.63
# Found fret number: 17 on string 1 at time 3.07
# Found fret number: 18 on string 1 at time 3.51
# Found fret number: 18 on string 1 at time 3.95
# Found fret number: 18 on string 1 at time 4.38
# Found fret number: 18 on string 1 at time 4.82
# Found fret number: 13 on string 1 at time 5.26
# Found fret number: 13 on string 1 at time 5.69
# Found fret number: 13 on string 1 at time 6.10
# Found fret number: 13 on string 1 at time 6.55
# Found fret number: 15 on string 1 at time 6.98
# Found fret number: 15 on string 1 at time 7.44
# Found fret number: 15 on string 1 at time 7.88
# Found fret number: 15 on string 1 at time 8.31
# Found fret number: 18 on string 1 at time 8.74
# Found fret number: 18 on string 1 at time 9.17
# Found fret number: 18 on string 1 at time 9.62
# Found fret number: 18 on string 1 at time 10.06
# Found fret number: 15 on string 1 at time 10.51
# Found fret number: 15 on string 1 at time 10.94
# Found fret number: 15 on string 1 at time 11.38
# Found fret number: 15 on string 1 at time 11.82
# Found fret number: 16 on string 1 at time 12.53
# Found fret number: 16 on string 1 at time 13.11
# Found fret number: 16 on string 1 at time 13.55
# Found fret number: 18 on string 1 at time 13.99
# Found fret number: 18 on string 1 at time 14.42
# Found fret number: 18 on string 1 at time 14.83
# Found fret number: 18 on string 1 at time 15.14
# Found fret number: 17 on string 1 at time 16.02
# Found fret number: 17 on string 1 at time 16.43
# Found fret number: 17 on string 1 at time 16.57
# Found fret number: 17 on string 1 at time 17.02
# Found fret number: 18 on string 1 at time 17.49
# Found fret number: 18 on string 1 at time 17.91
# Found fret number: 18 on string 1 at time 18.37
# Found fret number: 18 on string 1 at time 18.67
# Found fret number: 12 on string 1 at time 19.25
# Found fret number: 13 on string 1 at time 19.96
# Found fret number: 13 on string 1 at time 20.54
# Found fret number: 15 on string 1 at time 20.99
# Found fret number: 15 on string 1 at time 21.43
# Found fret number: 15 on string 1 at time 21.89
# Found fret number: 15 on string 1 at time 22.16
# Found fret number: 17 on string 1 at time 22.61
# Found fret number: 18 on string 1 at time 22.75
# Found fret number: 18 on string 1 at time 23.04
# Found fret number: 18 on string 1 at time 23.48
# Found fret number: 18 on string 1 at time 24.05
# Found fret number: 15 on string 1 at time 24.50
# Found fret number: 15 on string 1 at time 24.96
# Found fret number: 15 on string 1 at time 25.41
# Found fret number: 15 on string 1 at time 25.83
# Found fret number: 16 on string 1 at time 26.56
# Found fret number: 16 on string 1 at time 27.15
# Found fret number: 17 on string 2 at time 0.01
# Found fret number: 17 on string 2 at time 0.43
# Found fret number: 17 on string 2 at time 0.86
# Found fret number: 17 on string 2 at time 1.31
# Found fret number: 17 on string 2 at time 1.75
# Found fret number: 17 on string 2 at time 2.19
# Found fret number: 17 on string 2 at time 2.64
# Found fret number: 17 on string 2 at time 3.07
# Found fret number: 18 on string 2 at time 3.52
# Found fret number: 18 on string 2 at time 3.96
# Found fret number: 18 on string 2 at time 4.39
# Found fret number: 18 on string 2 at time 4.82
# Found fret number: 18 on string 1 at time 5.27
# Found fret number: 18 on string 1 at time 5.69
# Found fret number: 18 on string 1 at time 6.11
# Found fret number: 18 on string 1 at time 6.56
# Found fret number: 15 on string 2 at time 6.99
# Found fret number: 15 on string 2 at time 7.44
# Found fret number: 15 on string 2 at time 7.89
# Found fret number: 15 on string 2 at time 8.32
# Found fret number: 17 on string 2 at time 8.75
# Found fret number: 17 on string 2 at time 9.18
# Found fret number: 17 on string 2 at time 9.63
# Found fret number: 17 on string 2 at time 10.07
# Found fret number: 15 on string 2 at time 10.51
# Found fret number: 15 on string 2 at time 10.95
# Found fret number: 15 on string 2 at time 11.39
# Found fret number: 15 on string 2 at time 11.82
# Found fret number: 17 on string 2 at time 12.53
# Found fret number: 17 on string 2 at time 13.11
# Found fret number: 17 on string 2 at time 13.56
# Found fret number: 17 on string 2 at time 14.00
# Found fret number: 17 on string 2 at time 14.43
# Found fret number: 18 on string 2 at time 14.84
# Found fret number: 18 on string 2 at time 15.15
# Found fret number: 17 on string 2 at time 16.03
# Found fret number: 17 on string 2 at time 16.58
# Found fret number: 17 on string 2 at time 17.03
# Found fret number: 18 on string 2 at time 17.50
# Found fret number: 18 on string 2 at time 17.92
# Found fret number: 18 on string 2 at time 18.38
# Found fret number: 18 on string 2 at time 18.67
# Found fret number: 18 on string 1 at time 19.26
# Found fret number: 18 on string 1 at time 19.96
# Found fret number: 18 on string 1 at time 20.54
# Found fret number: 15 on string 2 at time 21.01
# Found fret number: 15 on string 2 at time 21.43
# Found fret number: 15 on string 2 at time 22.17
# Found fret number: 17 on string 2 at time 22.76
# Found fret number: 17 on string 2 at time 23.05
# Found fret number: 17 on string 2 at time 23.49
# Found fret number: 17 on string 2 at time 24.06
# Found fret number: 15 on string 2 at time 24.51
# Found fret number: 15 on string 2 at time 24.96
# Found fret number: 15 on string 2 at time 25.41
# Found fret number: 15 on string 2 at time 25.84
# Found fret number: 17 on string 2 at time 26.56
# Found fret number: 17 on string 2 at time 27.15
# Found fret number: 17 on string 3 at time 0.01
# Found fret number: 17 on string 3 at time 0.44
# Found fret number: 17 on string 3 at time 0.87
# Found fret number: 17 on string 3 at time 1.31
# Found fret number: 15 on string 3 at time 1.76
# Found fret number: 15 on string 3 at time 2.20
# Found fret number: 15 on string 3 at time 2.64
# Found fret number: 15 on string 3 at time 3.08
# Found fret number: 17 on string 3 at time 3.52
# Found fret number: 17 on string 3 at time 3.96
# Found fret number: 17 on string 3 at time 4.39
# Found fret number: 17 on string 3 at time 4.83
# Found fret number: 17 on string 2 at time 5.27
# Found fret number: 17 on string 2 at time 5.69
# Found fret number: 17 on string 2 at time 6.12
# Found fret number: 17 on string 2 at time 6.56
# Found fret number: 18 on string 2 at time 7.00
# Found fret number: 18 on string 2 at time 7.45
# Found fret number: 18 on string 2 at time 7.89
# Found fret number: 18 on string 2 at time 8.32
# Found fret number: 17 on string 3 at time 9.18
# Found fret number: 17 on string 3 at time 9.63
# Found fret number: 17 on string 3 at time 10.07
# Found fret number: 18 on string 2 at time 10.52
# Found fret number: 18 on string 2 at time 10.95
# Found fret number: 18 on string 2 at time 11.39
# Found fret number: 18 on string 2 at time 11.83
# Found fret number: 15 on string 3 at time 12.53
# Found fret number: 15 on string 3 at time 13.12
# Found fret number: 15 on string 3 at time 13.56
# Found fret number: 17 on string 3 at time 14.00
# Found fret number: 17 on string 3 at time 14.43
# Found fret number: 17 on string 3 at time 14.85
# Found fret number: 17 on string 3 at time 15.15
# Found fret number: 15 on string 3 at time 16.03
# Found fret number: 15 on string 3 at time 16.58
# Found fret number: 15 on string 3 at time 17.03
# Found fret number: 17 on string 3 at time 17.50
# Found fret number: 17 on string 3 at time 17.92
# Found fret number: 17 on string 3 at time 18.38
# Found fret number: 17 on string 3 at time 18.68
# Found fret number: 17 on string 2 at time 19.27
# Found fret number: 17 on string 2 at time 19.97
# Found fret number: 15 on string 2 at time 20.42
# Found fret number: 17 on string 2 at time 20.54
# Found fret number: 18 on string 2 at time 21.01
# Found fret number: 18 on string 2 at time 21.44
# Found fret number: 18 on string 2 at time 22.17
# Found fret number: 17 on string 3 at time 23.05
# Found fret number: 17 on string 3 at time 23.49
# Found fret number: 17 on string 3 at time 24.06
# Found fret number: 18 on string 2 at time 24.51
# Found fret number: 18 on string 2 at time 24.97
# Found fret number: 18 on string 2 at time 25.42
# Found fret number: 18 on string 2 at time 25.84
# Found fret number: 15 on string 3 at time 26.56
# Found fret number: 15 on string 3 at time 27.16
# Found fret number: 19 on string 4 at time 14.86
# Found fret number: 17 on string 4 at time 15.16
# Found fret number: 15 on string 5 at time 18.39
# Found fret number: 17 on string 4 at time 18.69
# Found fret number: 13 on string 1 at time 6.34
# Found fret number: 15 on string 1 at time 6.49
# Found fret number: 13 on string 1 at time 9.36
# Found fret number: 11 on string 1 at time 10.26
# Found fret number: 13 on string 1 at time 23.33
# Found fret number: 15 on string 1 at time 24.74
# Found fret number: 16 on string 1 at time 24.93
# Found fret number: 18 on string 1 at time 5.08
# Found fret number: 18 on string 1 at time 6.78
# Found fret number: 15 on string 2 at time 7.00
# Found fret number: 15 on string 2 at time 8.10
# Found fret number: 18 on string 1 at time 8.28
# Found fret number: 16 on string 1 at time 8.51
# Found fret number: 15 on string 1 at time 8.78
# Found fret number: 18 on string 1 at time 9.04
# Found fret number: 16 on string 1 at time 10.49
# Found fret number: 16 on string 1 at time 10.76
# Found fret number: 14 on string 2 at time 17.44
# Found fret number: 15 on string 2 at time 17.70
# Found fret number: 15 on string 2 at time 21.65
# Found fret number: 18 on string 1 at time 22.72
# Found fret number: 18 on string 1 at time 25.18
# Found fret number: 15 on string 2 at time 25.38
# Found fret number: 15 on string 3 at time 1.29
# Found fret number: 17 on string 2 at time 1.60
# Found fret number: 17 on string 2 at time 2.86
# Found fret number: 18 on string 2 at time 3.04
# Found fret number: 15 on string 3 at time 3.29
# Found fret number: 18 on string 2 at time 4.21
# Found fret number: 17 on string 2 at time 4.79
# Found fret number: 17 on string 2 at time 7.26
# Found fret number: 18 on string 2 at time 7.44
# Found fret number: 15 on string 3 at time 7.66
# Found fret number: 17 on string 2 at time 7.88
# Found fret number: 15 on string 2 at time 10.92
# Found fret number: 15 on string 2 at time 11.19
# Found fret number: 18 on string 2 at time 11.36
# Found fret number: 18 on string 2 at time 11.60
# Found fret number: 15 on string 3 at time 14.71
# Found fret number: 18 on string 2 at time 16.00
# Found fret number: 18 on string 2 at time 16.33
# Found fret number: 17 on string 2 at time 17.22
# Found fret number: 17 on string 2 at time 17.89
# Found fret number: 18 on string 2 at time 18.15
# Found fret number: 15 on string 3 at time 20.76
# Found fret number: 18 on string 2 at time 20.96
# Found fret number: 17 on string 2 at time 21.36
# Found fret number: 17 on string 2 at time 22.48
# Found fret number: 17 on string 2 at time 25.63
# Found fret number: 18 on string 2 at time 25.85
# Found fret number: 15 on string 3 at time 26.07
# Found fret number: 15 on string 4 at time 0.01
# Found fret number: 17 on string 3 at time 0.72
# Found fret number: 17 on string 3 at time 3.48
# Found fret number: 15 on string 3 at time 11.81
# Found fret number: 17 on string 3 at time 12.01
# Found fret number: 18 on string 3 at time 12.29
# Found fret number: 17 on string 3 at time 12.62
# Found fret number: 17 on string 3 at time 12.91
# Found fret number: 15 on string 4 at time 14.02
# Found fret number: 17 on string 3 at time 18.33
# Found fret number: 15 on string 4 at time 18.62
# Found fret number: 15 on string 4 at time 19.25
# Found fret number: 17 on string 3 at time 19.65
# Found fret number: 18 on string 3 at time 19.95
# Found fret number: 17 on string 3 at time 20.64
# Found fret number: 17 on string 3 at time 21.20
# Found fret number: 17 on string 3 at time 26.28
# Found fret number: 18 on string 3 at time 26.48
# Found fret number: 17 on string 3 at time 26.64
# Found fret number: 17 on string 3 at time 27.15
# Found fret number: 19 on string 4 at time 13.76
# Found fret number: 19 on string 4 at time 14.40
# Found fret number: 15 on string 5 at time 15.44
# Found fret number: 17 on string 4 at time 15.71
# Found fret number: 19 on string 4 at time 18.81
# Found fret number: 17 on string 4 at time 19.08
# Found fret number: 8 on string 1 at time 0.01
# Found fret number: 8 on string 1 at time 0.40
# Found fret number: 8 on string 1 at time 0.81
# Found fret number: 8 on string 1 at time 1.03
# Found fret number: 5 on string 1 at time 3.41
# Found fret number: 5 on string 1 at time 3.84
# Found fret number: 5 on string 1 at time 4.39
# Found fret number: 8 on string 1 at time 13.05
# Found fret number: 8 on string 1 at time 13.45
# Found fret number: 8 on string 1 at time 13.99
# Found fret number: 15 on string 1 at time 1.56
# Found fret number: 15 on string 1 at time 1.97
# Found fret number: 15 on string 1 at time 2.37
# Found fret number: 15 on string 1 at time 2.77
# Found fret number: 12 on string 1 at time 4.80
# Found fret number: 12 on string 1 at time 5.20
# Found fret number: 12 on string 1 at time 5.60
# Found fret number: 12 on string 1 at time 5.99
# Found fret number: 13 on string 1 at time 6.40
# Found fret number: 13 on string 1 at time 6.67
# Found fret number: 13 on string 1 at time 7.05
# Found fret number: 13 on string 1 at time 7.60
# Found fret number: 8 on string 1 at time 8.00
# Found fret number: 8 on string 1 at time 8.40
# Found fret number: 8 on string 1 at time 8.81
# Found fret number: 8 on string 1 at time 9.07
# Found fret number: 13 on string 1 at time 9.61
# Found fret number: 13 on string 1 at time 10.00
# Found fret number: 13 on string 1 at time 10.39
# Found fret number: 13 on string 1 at time 10.65
# Found fret number: 15 on string 1 at time 11.10
# Found fret number: 15 on string 1 at time 11.43
# Found fret number: 15 on string 1 at time 11.82
# Found fret number: 15 on string 1 at time 12.39
# Found fret number: 15 on string 1 at time 12.48
# Found fret number: 15 on string 1 at time 14.64
# Found fret number: 15 on string 1 at time 15.04
# Found fret number: 15 on string 1 at time 15.59
# Found fret number: 17 on string 1 at time 16.27
# Found fret number: 17 on string 1 at time 16.65
# Found fret number: 17 on string 1 at time 17.18
# Found fret number: 12 on string 1 at time 17.85
# Found fret number: 12 on string 1 at time 18.63
# Found fret number: 13 on string 1 at time 19.57
# Found fret number: 13 on string 1 at time 19.96
# Found fret number: 13 on string 1 at time 20.26
# Found fret number: 15 on string 1 at time 24.64
# Found fret number: 15 on string 1 at time 25.20
# Found fret number: 14 on string 2 at time 0.01
# Found fret number: 14 on string 2 at time 0.42
# Found fret number: 14 on string 2 at time 1.05
# Found fret number: 19 on string 1 at time 1.58
# Found fret number: 19 on string 1 at time 1.98
# Found fret number: 19 on string 1 at time 2.38
# Found fret number: 14 on string 2 at time 2.79
# Found fret number: 13 on string 1 at time 3.42
# Found fret number: 13 on string 1 at time 3.86
# Found fret number: 13 on string 1 at time 4.32
# Found fret number: 13 on string 1 at time 4.40
# Found fret number: 15 on string 1 at time 4.80
# Found fret number: 15 on string 1 at time 5.21
# Found fret number: 15 on string 1 at time 5.61
# Found fret number: 15 on string 1 at time 6.00
# Found fret number: 15 on string 2 at time 6.40
# Found fret number: 15 on string 2 at time 6.68
# Found fret number: 15 on string 2 at time 7.06
# Found fret number: 15 on string 2 at time 7.52
# Found fret number: 15 on string 2 at time 7.60
# Found fret number: 15 on string 1 at time 8.00
# Found fret number: 15 on string 1 at time 8.41
# Found fret number: 15 on string 1 at time 8.72
# Found fret number: 15 on string 1 at time 8.83
# Found fret number: 15 on string 1 at time 9.08
# Found fret number: 15 on string 2 at time 9.62
# Found fret number: 15 on string 2 at time 10.01
# Found fret number: 15 on string 2 at time 10.41
# Found fret number: 15 on string 2 at time 10.66
# Found fret number: 19 on string 1 at time 11.44
# Found fret number: 19 on string 1 at time 11.83
# Found fret number: 19 on string 1 at time 12.31
# Found fret number: 19 on string 1 at time 12.40
# Found fret number: 14 on string 2 at time 13.07
# Found fret number: 14 on string 2 at time 13.47
# Found fret number: 19 on string 1 at time 13.91
# Found fret number: 14 on string 2 at time 13.99
# Found fret number: 19 on string 1 at time 14.65
# Found fret number: 19 on string 1 at time 15.04
# Found fret number: 18 on string 1 at time 15.50
# Found fret number: 14 on string 2 at time 15.60
# Found fret number: 15 on string 2 at time 16.28
# Found fret number: 15 on string 2 at time 16.66
# Found fret number: 15 on string 2 at time 17.19
# Found fret number: 15 on string 2 at time 17.28
# Found fret number: 15 on string 1 at time 17.86
# Found fret number: 14 on string 2 at time 18.64
# Found fret number: 15 on string 2 at time 19.58
# Found fret number: 15 on string 2 at time 19.97
# Found fret number: 15 on string 2 at time 20.27
# Found fret number: 15 on string 2 at time 21.06
# Found fret number: 15 on string 2 at time 21.43
# Found fret number: 15 on string 2 at time 21.98
# Found fret number: 15 on string 2 at time 22.66
# Found fret number: 15 on string 2 at time 23.03
# Found fret number: 15 on string 2 at time 23.58
# Found fret number: 19 on string 1 at time 24.65
# Found fret number: 19 on string 1 at time 25.21
# Found fret number: 14 on string 3 at time 0.01
# Found fret number: 14 on string 3 at time 0.43
# Found fret number: 14 on string 3 at time 1.06
# Found fret number: 15 on string 3 at time 1.59
# Found fret number: 15 on string 3 at time 1.99
# Found fret number: 15 on string 3 at time 2.39
# Found fret number: 15 on string 3 at time 2.80
# Found fret number: 15 on string 2 at time 3.43
# Found fret number: 15 on string 2 at time 3.86
# Found fret number: 14 on string 2 at time 4.29
# Found fret number: 15 on string 2 at time 4.41
# Found fret number: 17 on string 2 at time 4.80
# Found fret number: 17 on string 2 at time 5.22
# Found fret number: 17 on string 2 at time 5.62
# Found fret number: 17 on string 2 at time 6.01
# Found fret number: 19 on string 2 at time 6.69
# Found fret number: 19 on string 2 at time 7.07
# Found fret number: 18 on string 2 at time 7.50
# Found fret number: 14 on string 3 at time 7.61
# Found fret number: 14 on string 2 at time 8.01
# Found fret number: 14 on string 2 at time 8.42
# Found fret number: 19 on string 1 at time 8.69
# Found fret number: 18 on string 1 at time 8.83
# Found fret number: 14 on string 2 at time 9.08
# Found fret number: 15 on string 3 at time 9.63
# Found fret number: 14 on string 3 at time 10.02
# Found fret number: 19 on string 2 at time 10.67
# Found fret number: 15 on string 3 at time 11.44
# Found fret number: 15 on string 3 at time 11.84
# Found fret number: 15 on string 3 at time 12.29
# Found fret number: 15 on string 3 at time 12.40
# Found fret number: 14 on string 3 at time 13.07
# Found fret number: 14 on string 3 at time 13.47
# Found fret number: 19 on string 2 at time 13.88
# Found fret number: 14 on string 3 at time 14.00
# Found fret number: 15 on string 3 at time 14.66
# Found fret number: 15 on string 3 at time 15.05
# Found fret number: 15 on string 3 at time 15.61
# Found fret number: 17 on string 3 at time 16.28
# Found fret number: 17 on string 3 at time 16.66
# Found fret number: 17 on string 3 at time 17.08
# Found fret number: 17 on string 3 at time 17.20
# Found fret number: 17 on string 2 at time 17.86
# Found fret number: 17 on string 2 at time 18.64
# Found fret number: 15 on string 3 at time 19.59
# Found fret number: 15 on string 3 at time 19.98
# Found fret number: 15 on string 3 at time 20.28
# Found fret number: 14 on string 3 at time 21.07
# Found fret number: 14 on string 3 at time 21.44
# Found fret number: 14 on string 3 at time 21.87
# Found fret number: 14 on string 3 at time 21.99
# Found fret number: 15 on string 3 at time 22.67
# Found fret number: 15 on string 3 at time 23.04
# Found fret number: 15 on string 3 at time 23.48
# Found fret number: 15 on string 3 at time 23.59
# Found fret number: 15 on string 3 at time 24.66
# Found fret number: 15 on string 3 at time 25.22
# Found fret number: 17 on string 3 at time 0.01
# Found fret number: 17 on string 3 at time 0.43
# Found fret number: 17 on string 3 at time 1.06
# Found fret number: 19 on string 3 at time 1.60
# Found fret number: 19 on string 3 at time 2.00
# Found fret number: 19 on string 3 at time 2.40
# Found fret number: 19 on string 3 at time 2.80
# Found fret number: 19 on string 2 at time 3.43
# Found fret number: 19 on string 2 at time 3.87
# Found fret number: 19 on string 2 at time 4.42
# Found fret number: 17 on string 3 at time 4.81
# Found fret number: 17 on string 3 at time 5.22
# Found fret number: 17 on string 3 at time 5.62
# Found fret number: 17 on string 3 at time 6.02
# Found fret number: 19 on string 3 at time 6.69
# Found fret number: 19 on string 3 at time 7.08
# Found fret number: 19 on string 3 at time 7.49
# Found fret number: 19 on string 3 at time 7.62
# Found fret number: 19 on string 2 at time 8.02
# Found fret number: 14 on string 3 at time 8.42
# Found fret number: 19 on string 2 at time 9.09
# Found fret number: 14 on string 4 at time 9.64
# Found fret number: 19 on string 3 at time 10.03
# Found fret number: 19 on string 3 at time 10.67
# Found fret number: 18 on string 3 at time 11.45
# Found fret number: 18 on string 3 at time 11.84
# Found fret number: 18 on string 3 at time 12.28
# Found fret number: 18 on string 3 at time 12.41
# Found fret number: 17 on string 3 at time 13.08
# Found fret number: 17 on string 3 at time 13.48
# Found fret number: 17 on string 3 at time 13.88
# Found fret number: 17 on string 3 at time 14.01
# Found fret number: 19 on string 3 at time 14.66
# Found fret number: 19 on string 3 at time 15.06
# Found fret number: 19 on string 3 at time 15.47
# Found fret number: 19 on string 3 at time 15.61
# Found fret number: 16 on string 4 at time 16.29
# Found fret number: 16 on string 4 at time 16.67
# Found fret number: 16 on string 4 at time 17.08
# Found fret number: 16 on string 4 at time 17.20
# Found fret number: 17 on string 3 at time 17.86
# Found fret number: 17 on string 3 at time 18.65
# Found fret number: 19 on string 3 at time 19.60
# Found fret number: 19 on string 3 at time 19.99
# Found fret number: 19 on string 3 at time 20.28
# Found fret number: 17 on string 3 at time 21.07
# Found fret number: 17 on string 3 at time 21.45
# Found fret number: 17 on string 3 at time 21.87
# Found fret number: 17 on string 3 at time 22.00
# Found fret number: 19 on string 3 at time 22.67
# Found fret number: 19 on string 3 at time 23.05
# Found fret number: 19 on string 3 at time 23.49
# Found fret number: 19 on string 3 at time 23.60
# Found fret number: 18 on string 3 at time 24.66
# Found fret number: 18 on string 3 at time 25.11
# Found fret number: 18 on string 3 at time 25.23
# Found fret number: 15 on string 5 at time 18.65
# Found fret number: 16 on string 4 at time 21.08
# Found fret number: 16 on string 4 at time 21.45
# Found fret number: 16 on string 4 at time 21.87
# Found fret number: 16 on string 4 at time 22.00
# Found fret number: 17 on string 5 at time 22.68
# Found fret number: 19 on string 4 at time 23.05
# Found fret number: 17 on string 5 at time 23.61
# Found fret number: 12 on string 1 at time 20.57
# Found fret number: 13 on string 1 at time 20.78
# Found fret number: 17 on string 1 at time 19.81
# Found fret number: 18 on string 1 at time 20.22
# Found fret number: 17 on string 1 at time 21.02
# Found fret number: 15 on string 2 at time 21.15
# Found fret number: 15 on string 2 at time 8.61
# Found fret number: 17 on string 2 at time 8.81
# Found fret number: 15 on string 3 at time 12.63
# Found fret number: 19 on string 2 at time 12.82
# Found fret number: 17 on string 2 at time 14.66
# Found fret number: 15 on string 2 at time 16.66
# Found fret number: 17 on string 2 at time 18.62
# Found fret number: 15 on string 2 at time 18.77
# Found fret number: 14 on string 2 at time 19.00
# Found fret number: 17 on string 2 at time 19.15
# Found fret number: 15 on string 2 at time 19.55
# Found fret number: 14 on string 3 at time 21.40
# Found fret number: 19 on string 2 at time 21.48
# Found fret number: 17 on string 3 at time 1.24
# Found fret number: 15 on string 3 at time 2.61
# Found fret number: 14 on string 3 at time 4.24
# Found fret number: 17 on string 2 at time 5.45
# Found fret number: 19 on string 2 at time 7.43
# Found fret number: 19 on string 2 at time 9.04
# Found fret number: 15 on string 3 at time 9.22
# Found fret number: 17 on string 3 at time 9.42
# Found fret number: 17 on string 3 at time 10.24
# Found fret number: 15 on string 3 at time 10.77
# Found fret number: 17 on string 3 at time 11.43
# Found fret number: 18 on string 3 at time 11.63
# Found fret number: 17 on string 3 at time 11.84
# Found fret number: 17 on string 3 at time 12.01
# Found fret number: 18 on string 3 at time 12.21
# Found fret number: 17 on string 3 at time 12.35
# Found fret number: 17 on string 3 at time 13.17
# Found fret number: 15 on string 3 at time 14.98
# Found fret number: 19 on string 2 at time 16.84
# Found fret number: 17 on string 3 at time 17.06
# Found fret number: 17 on string 3 at time 17.45
# Found fret number: 15 on string 3 at time 17.97
# Found fret number: 14 on string 3 at time 18.25
# Found fret number: 17 on string 3 at time 21.56
# Found fret number: 19 on string 3 at time 23.41
# Found fret number: 17 on string 3 at time 23.59
# Found fret number: 18 on string 3 at time 23.80
# Found fret number: 18 on string 3 at time 24.64
# Found fret number: 18 on string 3 at time 25.09
# Found fret number: 17 on string 3 at time 25.22
# Found fret number: 17 on string 5 at time 0.68
# Found fret number: 17 on string 4 at time 1.00
# Found fret number: 19 on string 4 at time 1.59
# Found fret number: 16 on string 4 at time 2.20
# Found fret number: 17 on string 4 at time 3.80
# Found fret number: 14 on string 4 at time 3.95
# Found fret number: 16 on string 4 at time 4.61
# Found fret number: 17 on string 3 at time 5.19
# Found fret number: 14 on string 4 at time 9.61
# Found fret number: 16 on string 4 at time 9.97
# Found fret number: 16 on string 4 at time 13.43
# Found fret number: 15 on string 5 at time 13.83
# Found fret number: 14 on string 4 at time 15.21
# Found fret number: 17 on string 4 at time 15.47
# Found fret number: 16 on string 4 at time 17.20
# Found fret number: 14 on string 4 at time 17.60
# Found fret number: 16 on string 4 at time 21.87
# Found fret number: 17 on string 4 at time 23.00
# Found fret number: 16 on string 4 at time 23.16
# Found fret number: 16 on string 4 at time 23.26
# Found fret number: 5 on string 1 at time 0.01
# Found fret number: 5 on string 1 at time 0.20
# Found fret number: 5 on string 1 at time 0.44
# Found fret number: 5 on string 1 at time 0.65
# Found fret number: 5 on string 1 at time 0.90
# Found fret number: 5 on string 1 at time 1.13
# Found fret number: 5 on string 1 at time 1.38
# Found fret number: 5 on string 1 at time 1.58
# Found fret number: 5 on string 1 at time 1.82
# Found fret number: 5 on string 1 at time 2.04
# Found fret number: 5 on string 1 at time 2.28
# Found fret number: 5 on string 1 at time 2.51
# Found fret number: 5 on string 1 at time 2.75
# Found fret number: 5 on string 1 at time 2.97
# Found fret number: 5 on string 1 at time 3.21
# Found fret number: 3 on string 1 at time 3.45
# Found fret number: 5 on string 1 at time 3.72
# Found fret number: 5 on string 1 at time 4.15
# Found fret number: 5 on string 1 at time 4.37
# Found fret number: 5 on string 1 at time 4.61
# Found fret number: 5 on string 1 at time 4.83
# Found fret number: 5 on string 1 at time 5.06
# Found fret number: 5 on string 1 at time 5.29
# Found fret number: 5 on string 1 at time 5.52
# Found fret number: 5 on string 1 at time 5.98
# Found fret number: 5 on string 1 at time 6.19
# Found fret number: 5 on string 1 at time 6.45
# Found fret number: 5 on string 1 at time 6.66
# Found fret number: 5 on string 1 at time 6.90
# Found fret number: 5 on string 1 at time 11.07
# Found fret number: 5 on string 1 at time 11.53
# Found fret number: 5 on string 1 at time 12.22
# Found fret number: 5 on string 1 at time 12.68
# Found fret number: 5 on string 1 at time 12.92
# Found fret number: 5 on string 1 at time 13.15
# Found fret number: 5 on string 1 at time 13.38
# Found fret number: 5 on string 1 at time 13.61
# Found fret number: 5 on string 1 at time 13.83
# Found fret number: 5 on string 1 at time 14.29
# Found fret number: 0 on string 1 at time 14.73
# Found fret number: 0 on string 1 at time 15.23
# Found fret number: 0 on string 1 at time 15.63
# Found fret number: 0 on string 1 at time 15.71
# Found fret number: 0 on string 1 at time 15.92
# Found fret number: 5 on string 1 at time 18.44
# Found fret number: 5 on string 1 at time 18.66
# Found fret number: 5 on string 1 at time 18.90
# Found fret number: 5 on string 1 at time 19.37
# Found fret number: 5 on string 1 at time 19.59
# Found fret number: 5 on string 1 at time 19.82
# Found fret number: 12 on string 1 at time 0.01
# Found fret number: 12 on string 1 at time 0.21
# Found fret number: 12 on string 1 at time 0.45
# Found fret number: 12 on string 1 at time 0.65
# Found fret number: 12 on string 1 at time 0.92
# Found fret number: 12 on string 1 at time 1.14
# Found fret number: 12 on string 1 at time 1.39
# Found fret number: 12 on string 1 at time 1.61
# Found fret number: 12 on string 1 at time 1.83
# Found fret number: 12 on string 1 at time 2.05
# Found fret number: 12 on string 1 at time 2.29
# Found fret number: 12 on string 1 at time 2.53
# Found fret number: 12 on string 1 at time 2.76
# Found fret number: 12 on string 1 at time 2.98
# Found fret number: 12 on string 1 at time 3.22
# Found fret number: 10 on string 1 at time 3.45
# Found fret number: 12 on string 1 at time 3.73
# Found fret number: 12 on string 1 at time 4.16
# Found fret number: 12 on string 1 at time 4.39
# Found fret number: 12 on string 1 at time 4.62
# Found fret number: 12 on string 1 at time 4.84
# Found fret number: 12 on string 1 at time 5.07
# Found fret number: 12 on string 1 at time 5.29
# Found fret number: 12 on string 1 at time 5.54
# Found fret number: 12 on string 1 at time 5.76
# Found fret number: 12 on string 1 at time 5.98
# Found fret number: 12 on string 1 at time 6.21
# Found fret number: 12 on string 1 at time 6.45
# Found fret number: 12 on string 1 at time 6.67
# Found fret number: 12 on string 1 at time 6.91
# Found fret number: 10 on string 1 at time 7.37
# Found fret number: 10 on string 1 at time 7.85
# Found fret number: 10 on string 1 at time 8.05
# Found fret number: 10 on string 1 at time 8.30
# Found fret number: 10 on string 1 at time 8.52
# Found fret number: 10 on string 1 at time 8.76
# Found fret number: 10 on string 1 at time 8.97
# Found fret number: 10 on string 1 at time 9.21
# Found fret number: 10 on string 1 at time 9.44
# Found fret number: 10 on string 1 at time 9.68
# Found fret number: 10 on string 1 at time 9.91
# Found fret number: 10 on string 1 at time 10.14
# Found fret number: 10 on string 1 at time 10.36
# Found fret number: 10 on string 1 at time 10.61
# Found fret number: 12 on string 1 at time 11.53
# Found fret number: 12 on string 1 at time 11.76
# Found fret number: 12 on string 1 at time 11.99
# Found fret number: 12 on string 1 at time 12.24
# Found fret number: 12 on string 1 at time 12.47
# Found fret number: 12 on string 1 at time 12.69
# Found fret number: 12 on string 1 at time 12.93
# Found fret number: 12 on string 1 at time 13.16
# Found fret number: 12 on string 1 at time 13.39
# Found fret number: 12 on string 1 at time 13.62
# Found fret number: 12 on string 1 at time 13.83
# Found fret number: 12 on string 1 at time 14.29
# Found fret number: 5 on string 1 at time 14.74
# Found fret number: 7 on string 1 at time 15.24
# Found fret number: 7 on string 1 at time 15.62
# Found fret number: 7 on string 1 at time 15.71
# Found fret number: 7 on string 1 at time 15.93
# Found fret number: 5 on string 1 at time 16.31
# Found fret number: 5 on string 1 at time 17.72
# Found fret number: 12 on string 1 at time 18.67
# Found fret number: 12 on string 1 at time 18.91
# Found fret number: 12 on string 1 at time 19.15
# Found fret number: 12 on string 1 at time 19.38
# Found fret number: 12 on string 1 at time 19.60
# Found fret number: 12 on string 1 at time 19.83
# Found fret number: 12 on string 1 at time 20.52
# Found fret number: 17 on string 1 at time 0.01
# Found fret number: 17 on string 1 at time 0.20
# Found fret number: 17 on string 1 at time 0.45
# Found fret number: 17 on string 1 at time 0.66
# Found fret number: 17 on string 1 at time 0.91
# Found fret number: 17 on string 1 at time 1.14
# Found fret number: 17 on string 1 at time 1.38
# Found fret number: 17 on string 1 at time 1.59
# Found fret number: 17 on string 1 at time 1.82
# Found fret number: 17 on string 1 at time 2.04
# Found fret number: 17 on string 1 at time 2.29
# ...
# Found fret number: 19 on string 3 at time 20.25
# Found fret number: 19 on string 3 at time 20.40
# Found fret number: 19 on string 3 at time 20.57
# Found fret number: 14 on string 4 at time 20.82
# Found fret number: 17 on string 3 at time 22.36
# Found fret number: 19 on string 3 at time 22.59
# Found fret number: 15 on string 4 at time 22.88
# Found fret number: 15 on string 4 at time 25.00
# Found fret number: 19 on string 3 at time 26.80
# Found fret number: 19 on string 3 at time 27.84
# Found fret number: 15 on string 4 at time 28.56
# Found fret number: 19 on string 3 at time 29.56
# Found fret number: 17 on string 3 at time 29.77
# Found fret number: 17 on string 3 at time 33.23
# Found fret number: 19 on string 3 at time 33.40
# Found fret number: 15 on string 4 at time 33.58
# Found fret number: 15 on string 4 at time 35.03
# Found fret number: 14 on string 4 at time 35.54
# Found fret number: 17 on string 3 at time 36.29
# Found fret number: 17 on string 3 at time 41.74
# Found fret number: 17 on string 3 at time 43.99
# Found fret number: 15 on string 3 at time 44.34
# Found fret number: 19 on string 4 at time 0.01
# Found fret number: 17 on string 4 at time 1.62
# Found fret number: 19 on string 4 at time 1.77
# Found fret number: 18 on string 5 at time 2.05
# Found fret number: 19 on string 4 at time 17.79
# Found fret number: 18 on string 5 at time 18.20
# Found fret number: 16 on string 5 at time 19.33
# Found fret number: 19 on string 4 at time 19.52
# Found fret number: 15 on string 5 at time 25.35
# Found fret number: 17 on string 4 at time 25.72
# Found fret number: 17 on string 4 at time 28.18
# Found fret number: 17 on string 4 at time 33.77
# Found fret number: 18 on string 4 at time 33.93
# Found fret number: 19 on string 4 at time 34.11
# Found fret number: 16 on string 5 at time 34.32
# Found fret number: 19 on string 4 at time 34.63
# Found fret number: 17 on string 4 at time 34.82
# Found fret number: 19 on string 4 at time 35.34
# Found fret number: 15 on string 4 at time 42.13
# Found fret number: 17 on string 4 at time 42.48
# Found fret number: 19 on string 3 at time 42.91
# Found fret number: 3 on string 1 at time 2.47
# Found fret number: 3 on string 1 at time 3.69
# Found fret number: 0 on string 1 at time 7.39
# Found fret number: 0 on string 1 at time 8.60
# Found fret number: 1 on string 1 at time 9.83
# Found fret number: 1 on string 1 at time 11.05
# Found fret number: 3 on string 1 at time 17.14
# Found fret number: 3 on string 1 at time 18.39
# Found fret number: 3 on string 1 at time 22.06
# Found fret number: 3 on string 1 at time 23.30
# Found fret number: 0 on string 1 at time 26.96
# Found fret number: 0 on string 1 at time 28.16
# Found fret number: 1 on string 1 at time 29.37
# Found fret number: 1 on string 1 at time 30.57
# Found fret number: 3 on string 1 at time 36.79
# Found fret number: 8 on string 1 at time 0.01
# Found fret number: 8 on string 1 at time 1.24
# Found fret number: 5 on string 1 at time 4.93
# Found fret number: 5 on string 1 at time 6.14
# Found fret number: 7 on string 1 at time 7.59
# Found fret number: 7 on string 1 at time 8.41
# Found fret number: 7 on string 1 at time 8.80
# Found fret number: 5 on string 1 at time 9.59
# Found fret number: 8 on string 1 at time 10.06
# Found fret number: 8 on string 1 at time 10.86
# Found fret number: 8 on string 1 at time 11.24
# Found fret number: 5 on string 1 at time 12.03
# Found fret number: 8 on string 1 at time 12.25
# Found fret number: 8 on string 1 at time 13.48
# Found fret number: 8 on string 1 at time 19.65
# Found fret number: 8 on string 1 at time 20.84
# Found fret number: 5 on string 1 at time 24.49
# Found fret number: 5 on string 1 at time 25.74
# Found fret number: 7 on string 1 at time 27.17
# Found fret number: 7 on string 1 at time 27.98
# Found fret number: 7 on string 1 at time 28.36
# Found fret number: 5 on string 1 at time 29.15
# Found fret number: 8 on string 1 at time 29.58
# Found fret number: 8 on string 1 at time 30.41
# Found fret number: 8 on string 1 at time 30.82
# Found fret number: 5 on string 1 at time 31.62
# Found fret number: 8 on string 1 at time 31.85
# Found fret number: 8 on string 1 at time 33.09
# Found fret number: 7 on string 1 at time 37.11
# Found fret number: 12 on string 1 at time 0.22
# Found fret number: 12 on string 1 at time 1.00
# Found fret number: 12 on string 1 at time 1.45
# Found fret number: 10 on string 1 at time 2.24
# Found fret number: 10 on string 1 at time 2.69
# Found fret number: 10 on string 1 at time 3.50
# Found fret number: 10 on string 1 at time 3.93
# Found fret number: 10 on string 1 at time 4.73
# Found fret number: 12 on string 1 at time 5.16
# Found fret number: 12 on string 1 at time 5.74
# Found fret number: 12 on string 1 at time 5.92
# Found fret number: 12 on string 1 at time 6.35
# Found fret number: 12 on string 1 at time 7.12
# Found fret number: 10 on string 1 at time 7.22
# Found fret number: 12 on string 1 at time 7.77
# Found fret number: 12 on string 1 at time 7.99
# Found fret number: 12 on string 1 at time 8.20
# Found fret number: 12 on string 1 at time 9.01
# Found fret number: 10 on string 1 at time 9.46
# Found fret number: 13 on string 1 at time 10.21
# Found fret number: 13 on string 1 at time 10.66
# Found fret number: 13 on string 1 at time 11.43
# Found fret number: 13 on string 1 at time 11.86
# Found fret number: 12 on string 1 at time 12.47
# Found fret number: 12 on string 1 at time 13.27
# Found fret number: 12 on string 1 at time 13.71
# Found fret number: 11 on string 1 at time 14.49
# Found fret number: 13 on string 1 at time 14.71
# Found fret number: 13 on string 1 at time 15.93
# Found fret number: 10 on string 1 at time 17.34
# Found fret number: 10 on string 1 at time 18.19
# Found fret number: 10 on string 1 at time 18.61
# Found fret number: 10 on string 1 at time 19.45
# Found fret number: 12 on string 1 at time 19.83
# Found fret number: 12 on string 1 at time 20.61
# Found fret number: 12 on string 1 at time 21.04
# Found fret number: 10 on string 1 at time 21.86
# Found fret number: 10 on string 1 at time 22.24
# Found fret number: 10 on string 1 at time 23.11
# Found fret number: 10 on string 1 at time 23.48
# Found fret number: 10 on string 1 at time 24.30
# Found fret number: 12 on string 1 at time 25.52
# Found fret number: 12 on string 1 at time 25.93
# Found fret number: 10 on string 1 at time 26.75
# Found fret number: 12 on string 1 at time 27.36
# Found fret number: 12 on string 1 at time 27.78
# Found fret number: 12 on string 1 at time 28.55
# Found fret number: 10 on string 1 at time 28.99
# Found fret number: 13 on string 1 at time 29.77
# Found fret number: 13 on string 1 at time 30.20
# Found fret number: 13 on string 1 at time 31.01
# Found fret number: 10 on string 1 at time 31.44
# Found fret number: 12 on string 1 at time 32.09
# Found fret number: 12 on string 1 at time 32.88
# Found fret number: 12 on string 1 at time 33.29
# Found fret number: 13 on string 1 at time 34.29
# Found fret number: 13 on string 1 at time 35.49
# Found fret number: 10 on string 1 at time 37.29
# Found fret number: 15 on string 1 at time 0.36
# Found fret number: 15 on string 1 at time 0.81
# Found fret number: 15 on string 1 at time 1.63
# Found fret number: 15 on string 1 at time 2.05
# Found fret number: 15 on string 1 at time 2.89
# Found fret number: 15 on string 1 at time 3.31
# Found fret number: 15 on string 1 at time 4.12
# Found fret number: 15 on string 1 at time 4.54
# Found fret number: 17 on string 1 at time 5.36
# Found fret number: 17 on string 1 at time 5.72
# Found fret number: 17 on string 1 at time 6.54
# Found fret number: 17 on string 1 at time 6.94
# Found fret number: 15 on string 1 at time 7.70
# Found fret number: 15 on string 1 at time 7.98
# Found fret number: 15 on string 1 at time 9.21
# Found fret number: 17 on string 1 at time 10.43
# Found fret number: 17 on string 1 at time 11.63
# Found fret number: 15 on string 1 at time 12.68
# Found fret number: 15 on string 1 at time 13.09
# Found fret number: 15 on string 1 at time 13.88
# Found fret number: 15 on string 1 at time 14.31
# Found fret number: 17 on string 1 at time 14.89
# Found fret number: 17 on string 1 at time 15.72
# Found fret number: 17 on string 1 at time 16.15
# Found fret number: 15 on string 1 at time 16.89
# Found fret number: 15 on string 1 at time 17.55
# Found fret number: 15 on string 1 at time 17.98
# Found fret number: 15 on string 1 at time 18.69
# Found fret number: 15 on string 1 at time 19.36
# Found fret number: 15 on string 1 at time 19.46
# Found fret number: 15 on string 1 at time 20.02
# Found fret number: 15 on string 1 at time 20.41
# Found fret number: 15 on string 1 at time 21.21
# Found fret number: 15 on string 1 at time 21.67
# Found fret number: 15 on string 1 at time 22.45
# Found fret number: 15 on string 1 at time 22.91
# Found fret number: 15 on string 1 at time 23.78
# Found fret number: 15 on string 1 at time 24.10
# Found fret number: 17 on string 1 at time 24.91
# Found fret number: 17 on string 1 at time 25.36
# Found fret number: 17 on string 1 at time 26.11
# Found fret number: 17 on string 1 at time 26.54
# Found fret number: 15 on string 1 at time 27.56
# Found fret number: 15 on string 1 at time 28.78
# Found fret number: 17 on string 1 at time 30.01
# Found fret number: 17 on string 1 at time 31.22
# Found fret number: 15 on string 1 at time 31.40
# Found fret number: 15 on string 1 at time 32.30
# Found fret number: 15 on string 1 at time 32.70
# Found fret number: 15 on string 1 at time 33.48
# Found fret number: 15 on string 1 at time 33.93
# Found fret number: 15 on string 1 at time 34.04
# Found fret number: 17 on string 1 at time 34.53
# Found fret number: 17 on string 1 at time 35.28
# Found fret number: 17 on string 1 at time 35.68
# Found fret number: 15 on string 1 at time 36.52
# Found fret number: 15 on string 1 at time 37.62
# Found fret number: 15 on string 2 at time 0.61
# Found fret number: 15 on string 2 at time 1.84
# Found fret number: 14 on string 2 at time 1.94
# Found fret number: 14 on string 2 at time 3.09
# Found fret number: 14 on string 2 at time 4.33
# Found fret number: 15 on string 2 at time 5.25
# Found fret number: 15 on string 2 at time 5.54
# Found fret number: 15 on string 2 at time 6.72
# Found fret number: 14 on string 2 at time 7.15
# Found fret number: 15 on string 2 at time 12.88
# Found fret number: 15 on string 2 at time 14.08
# Found fret number: 15 on string 2 at time 15.09
# Found fret number: 15 on string 2 at time 15.54
# Found fret number: 15 on string 2 at time 16.31
# Found fret number: 15 on string 2 at time 16.71
# Found fret number: 14 on string 2 at time 16.84
# Found fret number: 14 on string 2 at time 17.75
# Found fret number: 14 on string 2 at time 19.02
# Found fret number: 15 on string 2 at time 20.21
# Found fret number: 15 on string 2 at time 21.43
# Found fret number: 19 on string 1 at time 21.67
# Found fret number: 14 on string 2 at time 22.69
# Found fret number: 14 on string 2 at time 23.89
# Found fret number: 15 on string 2 at time 25.12
# Found fret number: 15 on string 2 at time 26.34
# Found fret number: 14 on string 2 at time 26.66
# Found fret number: 15 on string 2 at time 32.49
# Found fret number: 15 on string 2 at time 33.68
# Found fret number: 14 on string 2 at time 33.86
# Found fret number: 15 on string 2 at time 34.67
# Found fret number: 15 on string 2 at time 35.07
# Found fret number: 15 on string 2 at time 35.86
# Found fret number: 14 on string 2 at time 36.29
# Found fret number: 14 on string 2 at time 38.03
# Found fret number: 15 on string 3 at time 15.36
# Found fret number: 15 on string 3 at time 16.53
# Found fret number: 15 on string 3 at time 34.88
# Found fret number: 15 on string 3 at time 36.08
# Found fret number: 19 on string 2 at time 36.25
# Found fret number: 17 on string 3 at time 38.98
# Found fret number: 15 on string 1 at time 26.70
# Found fret number: 17 on string 1 at time 26.88
# Found fret number: 17 on string 1 at time 36.98
# Found fret number: 15 on string 1 at time 37.16
# Found fret number: 15 on string 2 at time 13.43
# Found fret number: 19 on string 1 at time 14.31
# Found fret number: 15 on string 2 at time 14.48
# Found fret number: 17 on string 1 at time 15.00
# Found fret number: 17 on string 1 at time 15.34
# Found fret number: 14 on string 2 at time 16.48
# Found fret number: 15 on string 2 at time 16.64
# Found fret number: 17 on string 2 at time 24.30
# Found fret number: 17 on string 2 at time 24.50
# Found fret number: 15 on string 2 at time 24.99
# Found fret number: 14 on string 2 at time 27.08
# Found fret number: 15 on string 2 at time 27.24
# Found fret number: 17 on string 2 at time 27.40
# Found fret number: 17 on string 2 at time 36.42
# Found fret number: 15 on string 2 at time 36.59
# Found fret number: 14 on string 2 at time 36.77
# Found fret number: 19 on string 2 at time 6.33
# Found fret number: 15 on string 3 at time 6.46
# Found fret number: 15 on string 3 at time 11.04
# Found fret number: 19 on string 2 at time 11.79
# Found fret number: 15 on string 3 at time 11.98
# Found fret number: 14 on string 3 at time 13.00
# Found fret number: 17 on string 2 at time 13.17
# Found fret number: 17 on string 2 at time 14.72
# Found fret number: 17 on string 2 at time 16.84
# Found fret number: 19 on string 2 at time 17.10
# Found fret number: 15 on string 3 at time 17.36
# Found fret number: 15 on string 3 at time 19.26
# Found fret number: 14 on string 3 at time 19.56
# Found fret number: 19 on string 2 at time 21.74
# Found fret number: 14 on string 3 at time 22.90
# Found fret number: 17 on string 3 at time 23.25
# Found fret number: 15 on string 3 at time 23.48
# Found fret number: 15 on string 3 at time 23.69
# Found fret number: 15 on string 3 at time 23.88
# Found fret number: 19 on string 2 at time 24.09
# Found fret number: 19 on string 2 at time 24.73
# Found fret number: 19 on string 2 at time 27.54
# Found fret number: 15 on string 3 at time 27.71
# Found fret number: 17 on string 3 at time 27.83
# Found fret number: 14 on string 3 at time 28.94
# Found fret number: 15 on string 3 at time 29.32
# Found fret number: 17 on string 3 at time 33.43
# Found fret number: 17 on string 3 at time 34.51
# Found fret number: 15 on string 3 at time 34.70
# Found fret number: 17 on string 3 at time 34.91
# Found fret number: 15 on string 3 at time 35.40
# Found fret number: 14 on string 3 at time 36.24
# Found fret number: 19 on string 2 at time 4.01
# Found fret number: 17 on string 3 at time 6.63
# Found fret number: 19 on string 3 at time 6.83
# Found fret number: 19 on string 3 at time 10.77
# Found fret number: 17 on string 3 at time 12.24
# Found fret number: 17 on string 3 at time 17.64
# Found fret number: 17 on string 3 at time 18.09
# Found fret number: 18 on string 3 at time 18.65
# Found fret number: 17 on string 3 at time 18.93
# Found fret number: 16 on string 4 at time 20.52
# Found fret number: 19 on string 3 at time 27.99
# Found fret number: 16 on string 4 at time 28.17
# Found fret number: 16 on string 4 at time 28.35
# Found fret number: 16 on string 4 at time 28.52
# Found fret number: 16 on string 4 at time 28.70
# Found fret number: 19 on string 3 at time 30.22
# Found fret number: 17 on string 4 at time 30.35
# Found fret number: 16 on string 4 at time 30.47
# Found fret number: 15 on string 5 at time 31.24
# Found fret number: 17 on string 4 at time 32.58
# Found fret number: 16 on string 4 at time 32.77
# Found fret number: 17 on string 4 at time 33.03
# Found fret number: 19 on string 4 at time 33.15
# Found fret number: 16 on string 4 at time 35.18
# Found fret number: 19 on string 3 at time 0.03
# Found fret number: 17 on string 3 at time 1.95
# Found fret number: 19 on string 3 at time 2.14
# Found fret number: 16 on string 4 at time 2.46
# Found fret number: 14 on string 4 at time 4.28
# Found fret number: 16 on string 4 at time 4.59
# Found fret number: 17 on string 4 at time 4.92
# Found fret number: 16 on string 4 at time 7.01
# Found fret number: 17 on string 4 at time 7.16
# Found fret number: 19 on string 4 at time 7.42
# Found fret number: 17 on string 4 at time 9.30
# Found fret number: 19 on string 4 at time 9.46
# Found fret number: 17 on string 5 at time 9.78
# Found fret number: 17 on string 4 at time 10.54
# Found fret number: 15 on string 5 at time 30.54
# Found fret number: 17 on string 5 at time 30.71
# Found fret number: 15 on string 6 at time 30.99

# %%
#@title Working & Current Attempt At Processing Tab (text) Files into Correct Format With Some Spacing Issues
import os
import jams
import numpy as np

def generate_tabs_from_jams(dataset_dir):
    annotation_dir = os.path.join(dataset_dir, "annotation")
    tabs_dir = os.path.join(dataset_dir, "TabsNoBarsLongerDuration")
    os.makedirs(tabs_dir, exist_ok=True)

    for filename in os.listdir(annotation_dir):
        if filename.endswith(".jams"):
            jams_file_path = os.path.join(annotation_dir, filename)
            generate_tab_for_file(jams_file_path, tabs_dir)

def generate_tab_for_file(jams_file_path, tabs_dir):
    jam = jams.load(jams_file_path)
    tab_data = process_jam_to_tab(jam)
    #print(f"Contents of tab_data for {jams_file_path}:")
    #for string, notes in tab_data.items():
        #print(f"String: {string}, Notes: {notes}")
    print_tab_data(tab_data, jams_file_path, tabs_dir)

def process_jam_to_tab(jam):
    string_midi_pitches = [40, 45, 50, 55, 59, 64]
    tab_data = {1: [], 2: [], 3: [], 4: [], 5: [], 6: []}

    for anno in jam.annotations:
        if anno.namespace == 'note_midi':
            for note in anno.data:
                midi_pitch = note.value
                string_number, fret_number = find_string_and_fret(midi_pitch, string_midi_pitches)
                if string_number is not None and fret_number is not None:
                    rounded_fret = round(fret_number)
                    tab_data[string_number].append((note.time, rounded_fret))

    for string_number in tab_data:
        tab_data[string_number].sort(key=lambda x: x[0])

    return tab_data

def find_string_and_fret(midi_pitch, string_midi_pitches):
    for string_number, open_string_pitch in enumerate(string_midi_pitches):
        if midi_pitch >= open_string_pitch and midi_pitch <= open_string_pitch + 19:
            fret_number = midi_pitch - open_string_pitch
            return string_number + 1, fret_number
    return None, None

def format_tab_line(tab_data, tab_length):
    tab_line = []
    dashes_per_second = 10
    last_time = 0
    last_fret_isNumb = False

    for time, fret in tab_data:
        #position = int(time * 100) # 1/100th second steps to ensure enough space (overcrowding can cause notes to "squish" together). Downside is this makes the tabs a bit long
        fret_str = str(fret)
        #print(fret_str)
        #print(fret_str)
        fret_len = len(fret_str)
        time_difference = time - last_time
        num_dashes = int(time_difference * dashes_per_second)

        if last_fret_isNumb:
          num_dashes = num_dashes = max(0, num_dashes - 1)
          last_fret_isNumb = False

        tab_line.extend(['-'] * num_dashes)


        #required_length = position + fret_len + 1
        #if len(tab_line) < required_length:
            # Extend tab_line with dashes to reach the required length
            #tab_line.extend(['-'] * (required_length - len(tab_line)))


        """
        # Ensure valid position before inserting a dash
        if position > 0 and tab_line[position - 1] != '-':
            #print("Replacement Triggered at position", position)
            #print("Start:", tab_line[position - 1], "End: ", tab_line[position + 1])
            tab_line = tab_line[:position] + ['-'] + tab_line[position:]
            #tab_line.insert(position - 1, '-')
            position = position + 1
        """


        # Insert a dash then fret num into the tab line


        tab_line.append(fret_str)

        if fret_str.isdigit():
          last_fret_isNumb = True
          tab_line.append("-")

        last_time = time

    return ''.join(tab_line)


def print_tab_data(tab_data, jams_file_path, tabs_dir):
    max_time = max(max(notes, key=lambda x: x[0])[0] if notes else 0 for notes in tab_data.values())
    tab_length = int(max_time * 10)

    tab_representation = {}
    for string_number, notes in tab_data.items():
        tab_representation[string_number] = format_tab_line(notes, tab_length)

    max_len = max(len(line) for line in tab_representation.values())
    for string_number in tab_representation:
        current_len = len(tab_representation[string_number])
        if current_len < max_len:
            tab_representation[string_number] += '-' * (max_len - current_len)

    string_labels = {1: "e|", 2: "B|", 3: "G|", 4: "D|", 5: "A|", 6: "E|"}
    base_filename = os.path.basename(jams_file_path).replace(".jams", ".txt")
    tab_filename = os.path.join(tabs_dir, base_filename)

    with open(tab_filename, 'w') as f:
        for string_number in range(6, 0, -1):
            f.write(f"{string_labels[string_number]}{tab_representation[string_number]}\n")

dataset_dir = '/content/drive/MyDrive/Summer2024Research/GuitarSet'
generate_tabs_from_jams(dataset_dir)

#FINALLY WORKS!

# %%
#@title Spectrogram Processing


import os
import librosa
import numpy as np
import matplotlib.pyplot as plt

def generate_mel_spectrograms(dataset_dir, save_dir, target_length=None, n_fft=4096, hop_length=256, n_mels=512):
    os.makedirs(save_dir, exist_ok=True)

    max_length = 0  # Variable to track the maximum length

    for filename in os.listdir(dataset_dir):
        if filename.endswith(".wav"):
            wav_file_path = os.path.join(dataset_dir, filename)

            # Load the audio file
            y, sr = librosa.load(wav_file_path, sr=None)

            # If stereo audio, convert to mono
            if len(y.shape) == 2:
                y = librosa.to_mono(y)

            # Compute the mel-spectrogram
            mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels)

            # Convert to log scale (dB)
            mel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)

            # Update the maximum length
            max_length = max(max_length, mel_spectrogram.shape[1])

            # Pad or truncate the spectrogram to the target length (if provided)
            if target_length:
                if mel_spectrogram.shape[1] < target_length:
                    padding = target_length - mel_spectrogram.shape[1]
                    mel_spectrogram = np.pad(mel_spectrogram, ((0, 0), (0, padding)), mode='constant')
                else:
                    mel_spectrogram = mel_spectrogram[:, :target_length]

            # Save the mel-spectrogram as a .npy file
            npy_filename = filename.replace('.wav', '.npy')
            np.save(os.path.join(save_dir, npy_filename), mel_spectrogram)

            # Plot and save the spectrogram image (for reference)
            plt.figure(figsize=(10, 4))
            librosa.display.specshow(mel_spectrogram, sr=sr, x_axis='time', y_axis='mel')
            plt.colorbar(format='%+2.0f dB')
            plt.title(f'Mel-Spectrogram: {filename}')
            plt.show()
            plt.close()

            # Display file name and spectrogram
            print(f"Processed {filename}, Spectrogram shape: {mel_spectrogram.shape}")

    # Print the maximum length found
    print(f"Largest number of time steps found: {max_length}")

# Example usage
dataset_dir = '/content/drive/MyDrive/Summer2024Research/GuitarSet/audio/audio_mic'
output_dir = '/content/drive/MyDrive/Summer2024Research/GuitarSet/melSpectrograms'
target_length = 4000  # Example target length (number of time steps), can be None to disable, change to 3937 if 4000 causes problems
generate_mel_spectrograms(dataset_dir, output_dir, target_length)

# %%
# Version where I manually one-hot encode

import os
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

tab_dir = "/content/drive/MyDrive/Summer2024Research/GuitarSet/TabsNoBarsLongerDuration"
spectrogram_dir = "/content/drive/MyDrive/Summer2024Research/GuitarSet/melSpectrograms"

def encode_tab_file(tab_file_path):
    encoding_map = {
        'e': 0, 'B': 1, 'G': 2, 'D': 3, 'A': 4, 'E': 5,
        '|': 6, '-': 7,
        **{str(i): 8 + i for i in range(20)}  # Map fret numbers 0-19 starting from index 8
    }

    encoded_tabs = []

    try:
        with open(tab_file_path, 'r') as file:
            #print()
            #print("New file:", tab_file_path)
            current_string_index = None
            skipCharacter = False
            #print(tab_file_path)
            for line in file:
                stripped_line = line.strip()
                #print(f"Processing line: {stripped_line}")  # Print each line being processed

                if stripped_line and stripped_line[0] in encoding_map:
                    current_string_index = encoding_map[stripped_line[0]]
                    #print(f"Identified string: {stripped_line[0]}, index: {current_string_index}")  # Print identified string

                if current_string_index is not None:
                    for i, char in enumerate(stripped_line):
                        if skipCharacter:
                            skipCharacter = False
                            continue

                        charToAppend = ""
                        if i + 1 < len(stripped_line) and (char + stripped_line[i + 1]).isdigit():
                            charToAppend = char + stripped_line[i + 1]
                            skipCharacter = True
                            #print(f"Detected two-digit fret: {charToAppend}")  # Debug two-digit fret

                        else:
                            charToAppend = char

                        encoded_value = encoding_map.get(charToAppend, 7)
                        encoded_tabs.append(encoded_value)
                        #print(f"Encoded character: {charToAppend}, value: {encoded_value}")  # Print each encoded character and its value


    except Exception as e:
        print(f"Error processing file {tab_file_path}: {e}")

    print(f"Final encoded tabs: {encoded_tabs}")
    return encoded_tabs



def load_data(spectrogram_dir, tab_dir):
    spectrograms = []
    encoded_tabs = []
    max_tab_length = 0

    for filename in os.listdir(spectrogram_dir):
        if filename.endswith('.npy'):
            # Load the spectrogram
            spectrogram = np.load(os.path.join(spectrogram_dir, filename))
            spectrograms.append(spectrogram)

            # Load and encode the corresponding tab file
            tab_filename = filename.replace('_mic.npy', '.txt')
            tab_file_path = os.path.join(tab_dir, tab_filename)

            if os.path.exists(tab_file_path):
                encoded_tab = encode_tab_file(tab_file_path)
                encoded_tabs.append(encoded_tab)

                # Update max_tab_length if necessary
                if len(encoded_tab) > max_tab_length:
                    max_tab_length = len(encoded_tab)

    # Pad all encoded tabs to the maximum length
    print(max_tab_length)
    for i in range(len(encoded_tabs)):
        if len(encoded_tabs[i]) < max_tab_length:
          encoded_tabs[i] += [7] * (max_tab_length - len(encoded_tabs[i]))
          #print("New length", len(encoded_tabs[i]))

    print(f"Shape of spectrograms array: {np.array(spectrograms).shape}")
    print(f"Shape of encoded tabs array: {np.array(encoded_tabs).shape}")

    return np.array(spectrograms), np.array(encoded_tabs)

# Load the data
X, y = load_data(spectrogram_dir, tab_dir)

# Normalize X
X = np.array(X) / np.max(X)

# X should have shape (batch_size, height, width, 1)
X = np.expand_dims(X, axis=-1)

num_classes = len(np.unique(np.concatenate(y)))
print("Num Classes:", num_classes)

y_one_hot = to_categorical(y, num_classes=num_classes)


# Split data into training and test sets
X_train, X_test, y_train_one_hot, y_test_one_hot = train_test_split(X, y_one_hot, test_size=0.2, random_state=42)

#num_classes = len(set(np.concatenate(y_train)))  # Adjust based on the actual unique values

#y_train_one_hot = to_categorical(y_train, num_classes=num_classes)
#y_test_one_hot = to_categorical(y_test, num_classes=num_classes)

# np.set_printoptions(threshold=np.inf)
# print()
# print("Contents of first from train set encoded categorically:")
# print(y_train_one_hot[0])
# Out:
# Final encoded tabs: [5, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 4, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7 ...
# Final encoded tabs: [5, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 4, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 25, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 3, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 22, 7, 7, 23, 7, 7, 26, 7, 7, 7, 7, 24, 7, 7, 7, 7, 7, 7, 24, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 26, 7, 7, 24, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 26, 7, 26, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 22, 7, 7, 24, 7, 7, 7, 7, 26, 7, 24, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 2, 6, 7, 7, 7, 7, 7, 7, 24, 7, 7, 25, 7, 7, 7, 27, 7, 7, 25, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 25, 7, 24, 7, 7, 7, 25, 7, 7, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 24, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 22, 7, 25, 7, 25, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 26, 7, 7, 27, 7, 7, 7, 7, 7, 7, 7, 7, 7, 24, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 24, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 27, 7, 7, 24, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 1, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, ...
# Final encoded tabs: [5, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 4, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 24, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 3, 6, 23, 7, 27, 7, 7, 7, 7, 7, 22, 7, 25, 7, 7, 7, 7, 7, 23, 7, 7, 25, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 22, 7, 25, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 22, 7, 25, 7, 7, 7, 7, 23, 7, 7, 23, 7, 27, 7, 7, 7, 7, 25, 7, 7, 7, 7, 7, 23, 7, 27, 7, 7, 22, 7, 25, 7, 7, 7, 7, 23, 7, 27, 7, 7, 7, 7, 22, 7, 25, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 22, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 25, 7, 7, 23, 7, 26, 7, 7, 7, 7, 7, 25, 7, 7, 7, 7, 7, 23, 7, 7, 25, 7, 7, 7, 7, 23, 7, 27, 7, 7, 7, 7, 22, 7, 25, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 25, 7, 7, 7, 23, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 22, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 2, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 25, 7, 7, 27, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 25, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 25, 7, 7, 7, 7, 7, 7, 7, 26, 7, 7, 7, 23, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 25, 7, 7, 7,  ...
# Final encoded tabs: [5, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 4, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 3, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7 ...
# Final encoded tabs: [5, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 4, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 3, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, ...
# Final encoded tabs: [5, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 4, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 3, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7 ...
# Final encoded tabs: [5, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 4, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 3, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 24, 7, 7, 7, 7, 7, 24, 7, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 24, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 24, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,  ...
# Final encoded tabs: [5, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 4, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 3, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 24, 7, 7, 25, 7, 7, 25, 7, 7, 7, 7, 7, 7, 7, 7, 24, 7, 7, 25, 7, 7, 23, 7, 7, 7, 22, 7, 7, 23, 7, 7, 25, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 2, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 26, 7, 7, 7, 7, 7, 26, 7, 7, 25, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 26, 7, 7, 24, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7 ...
# Final encoded tabs: [5, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 4, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 3, 6, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, ...
# Final encoded tabs: [5, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 4, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 3, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7 ...
# Final encoded tabs: [5, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 4, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 3, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 2, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7 ...
# ...
# Final encoded tabs: [5, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 4, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 25, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 3, 6, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 26, 7, 7, 7, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 2, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 25, 7, 7, 23, 7, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 22, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 22, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 25, 7, 23, 7, 7, 25, 7, 7, 7, 7, 23, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 25, 7, 7, 7, 7, 7, 27, 7, 7, 25, 7, 7, 7, 7, 7, 7, 27, 7, 7, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 25, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 25, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 1, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 27, 7, 7, 7, 7, 7, 25, 7, 7, 7, 7, 25, 7, 27, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 25, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 25, 7, 7, 23, 7, 7, 7, 7, 23, 7, 25, 7, 7, 7, 7, 7, 7, 7, 7, 25, 7, 7, 7,  ...
# Final encoded tabs: [5, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 4, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 25, 7, 7, 7, 25, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 25, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 24, 7, 24, 7, 24, 7, 25, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 3, 6, 7, 7, 7, 7, 7, 7, 22, 7, 7, 7, 7, 22, 7, 7, 7, 7, 7, 7, 7, 22, 7, 22, 7, 7, 7, 7, 7, 7, 7, 7, 24, 7, 7, 24, 7, 24, 7, 7, 7, 7, 24, 7, 7, 24, 7, 24, 7, 7, 7, 7, 7, 7, 7, 22, 7, 26, 7, 7, 7, 7, 7, 7, 26, 7, 7, 7, 7, 7, 7, 22, 7, 7, 7, 22, 7, 26, 7, 22, 7, 7, 7, 7, 7, 7, 7, 26, 7, 7, 26, 7, 7, 26, 7, 7, 7, 7, 26, 7, 7, 26, 7, 7, 7, 7, 7, 26, 7, 7 ...
# Final encoded tabs: [5, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 4, 6, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 3, 6, 22, 7, 23, 7, 7, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 23, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 22, 7, 23, 7, 23, 7, 23, 7, 7, 7, 23, 7, 7, 25, 7, 25, 7, 25, 7, 7, 7, 7, 7, 25, 7, 25, 7, 25, 7, 7, 23, 7, 7, 7, 7, 23, 7, 7, 7, 22, 7, 23, 7, 7, 23, 7, 7, 7, 23, 7, 23, 7, 7, 23, 7, 7, 7, 7, 23, 7, 7, 7, 7, 23, 7, 23, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 23, 7, 7, 23 ...
# 6934
# Shape of spectrograms array: (360, 512, 4000)
# Shape of encoded tabs array: (360, 6934)
# Num Classes: 28

# %%
#@title Custom Categorical Cross Entropy Loss Function With 10x Penalty For False Positives of "-"

import tensorflow as tf
import tensorflow.keras.backend as K

def focal_categorical_crossentropy(gamma=2., alpha=.25):
    def focal_loss(y_true, y_pred):
        # Clip the prediction value to prevent NaN's and Inf's
        epsilon = K.epsilon()
        y_pred = K.clip(y_pred, epsilon, 1. - epsilon)

        # Convert y_true to the same dtype as y_pred
        y_true = tf.cast(y_true, y_pred.dtype)

        # Calculate Cross Entropy
        cross_entropy = -y_true * K.log(y_pred)

        # Calculate Focal Loss
        loss = alpha * K.pow(1 - y_pred, gamma) * cross_entropy

        # Sum over classes
        loss = K.sum(loss, axis=-1)

        # Return mean loss
        return K.mean(loss)

    return focal_loss

# %%
#@title Displays Our Classes by the Inverse of their Frequency

from sklearn.utils import class_weight
import numpy as np

# Assuming y_train_one_hot is your one-hot encoded labels

# Convert the one-hot encoded labels back to their original class labels
y_train_flat = np.argmax(y_train_one_hot, axis=-1).flatten()

# Calculate class weights
class_weights = class_weight.compute_class_weight(class_weight='balanced', classes=np.unique(y_train_flat), y=y_train_flat)

# Convert to a dictionary format to easily map class indices to their weights
class_weights_dict = dict(enumerate(class_weights))

# Display the class weights
print("Class Weights:")
for class_index, weight in class_weights_dict.items():
    print(f"Class {class_index}: {weight}")
# Out:
# Class Weights:
# Class 0: 247.64285714285714
# Class 1: 247.64285714285714
# Class 2: 247.64285714285714
# Class 3: 247.64285714285714
# Class 4: 247.64285714285714
# Class 5: 247.64285714285714
# Class 6: 41.273809523809526
# Class 7: 0.03669368204659326
# Class 8: 186.70456245325354
# Class 9: 161.36005171299288
# Class 10: 177.8582116138226
# Class 11: 135.59152634437805
# Class 12: 114.8488612836439
# Class 13: 84.20441895766571
# Class 14: 97.56654289622826
# Class 15: 78.11735252699108
# Class 16: 68.11952517396644
# Class 17: 49.254932912391475
# Class 18: 56.38035008469791
# Class 19: 52.02125664270084
# Class 20: 46.493574222387785
# Class 21: 34.57156706599266
# Class 22: 12.444798963033127
# Class 23: 8.768274263233693
# Class 24: 9.711484593837534
# Class 25: 10.343893090231017
# Class 26: 10.241404775580536
# Class 27: 60.08520880972439

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Reshape, Dense, TimeDistributed, Add, MultiHeadAttention, LayerNormalization, Dropout, Layer
import numpy as np
from tensorflow.keras.losses import CategoricalFocalCrossentropy

loss_fn = CategoricalFocalCrossentropy(gamma=3.0, alpha=[1.0] * 28)

# Define Positional Encoding Layer
class PositionalEncoding(Layer):
    def __init__(self, sequence_length, d_model):
        super(PositionalEncoding, self).__init__()
        self.positional_encoding = self.get_positional_encoding(sequence_length, d_model)

    def get_positional_encoding(self, sequence_length, d_model):
        position = np.arange(sequence_length)[:, np.newaxis]
        div_term = np.exp(np.arange(0, d_model, 2) * -(np.log(10000.0) / d_model))
        positional_encoding = np.zeros((sequence_length, d_model))
        positional_encoding[:, 0::2] = np.sin(position * div_term)
        positional_encoding[:, 1::2] = np.cos(position * div_term)
        return tf.cast(positional_encoding[np.newaxis, ...], dtype=tf.float32)

    def call(self, inputs):
        return inputs + self.positional_encoding[:, :tf.shape(inputs)[1], :]

# Define Transformer Block
def transformer_block(inputs, num_heads, d_model, ff_dim, dropout=0.1):
    attention_output = MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(inputs, inputs)
    attention_output = Dropout(dropout)(attention_output)
    attention_output = LayerNormalization(epsilon=1e-6)(attention_output + inputs)

    ff_output = Dense(ff_dim, activation='relu')(attention_output)
    ff_output = Dense(d_model)(ff_output)
    ff_output = Dropout(dropout)(ff_output)
    ff_output = LayerNormalization(epsilon=1e-6)(ff_output + attention_output)

    return ff_output

# Model Architecture
input_layer = Input(shape=(512, 4000))  # Adjusted to 512 Mel bins

# Add a channel dimension for Conv2D
x = Reshape((512, 4000, 1))(input_layer)

# First Convolution + Pooling layer
x = Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2, 2), strides=(1, 2))(x)  # Downsample

# Second Convolution + Pooling layer
x = Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2, 2), strides=(1, 2))(x)  # Downsample

# Third Convolution + Pooling layer
x = Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2, 2), strides=(1, 2))(x)  # Downsample

# Flatten and reshape for transformer
x = Flatten()(x)
flattened_size = x.shape[-1]
target_size = 6934 * 128

# Calculate the correct shape if it's close
crop_amount = flattened_size - target_size
if crop_amount > 0:
    x = Reshape((6934, 128))(x[:, :target_size])  # Crop to fit target
else:
    raise ValueError(f"Flattened size ({flattened_size}) is smaller than the target ({target_size}). Adjust architecture.")

# Add positional encoding
sequence_length, d_model = 6934, 128
x = PositionalEncoding(sequence_length, d_model)(x)

# Transformer blocks
num_heads = 8
ff_dim = 512
num_transformer_blocks = 4

for _ in range(num_transformer_blocks):
    x = transformer_block(x, num_heads=num_heads, d_model=d_model, ff_dim=ff_dim)

# Fully connected layers
x = TimeDistributed(Dense(512, activation='relu'))(x)

# Output layer with 28 classes
output_layer = TimeDistributed(Dense(28, activation='softmax'))(x)

# Compile the model
model = Model(inputs=input_layer, outputs=output_layer)
model.compile(optimizer='adam', loss=loss_fn)

# Model summary
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 512, 4000)]          0         []
#
#  reshape_2 (Reshape)         (None, 512, 4000, 1)         0         ['input_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 512, 4000, 32)        320       ['reshape_2[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 511, 2000, 32)        0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 511, 2000, 64)        18496     ['max_pooling2d_3[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 510, 1000, 64)        0         ['conv2d_4[0][0]']
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 510, 1000, 128)       73856     ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 509, 500, 128)        0         ['conv2d_5[0][0]']
#  g2D)
#
#  flatten_1 (Flatten)         (None, 32576000)             0         ['max_pooling2d_5[0][0]']
#
#  tf.__operators__.getitem_1  (None, 887552)               0         ['flatten_1[0][0]']
#   (SlicingOpLambda)
#
#  reshape_3 (Reshape)         (None, 6934, 128)            0         ['tf.__operators__.getitem_1[0
#                                                                     ][0]']
#
#  positional_encoding_1 (Pos  (None, 6934, 128)            0         ['reshape_3[0][0]']
#  itionalEncoding)
#
#  multi_head_attention_4 (Mu  (None, 6934, 128)            527488    ['positional_encoding_1[0][0]'
#  ltiHeadAttention)                                                  , 'positional_encoding_1[0][0]
#                                                                     ']
#
#  dropout_8 (Dropout)         (None, 6934, 128)            0         ['multi_head_attention_4[0][0]
#                                                                     ']
#
#  tf.__operators__.add_8 (TF  (None, 6934, 128)            0         ['dropout_8[0][0]',
#  OpLambda)                                                           'positional_encoding_1[0][0]'
#                                                                     ]
#
#  layer_normalization_8 (Lay  (None, 6934, 128)            256       ['tf.__operators__.add_8[0][0]
#  erNormalization)                                                   ']
#
#  dense_10 (Dense)            (None, 6934, 512)            66048     ['layer_normalization_8[0][0]'
#                                                                     ]
#
#  dense_11 (Dense)            (None, 6934, 128)            65664     ['dense_10[0][0]']
#
#  dropout_9 (Dropout)         (None, 6934, 128)            0         ['dense_11[0][0]']
#
#  tf.__operators__.add_9 (TF  (None, 6934, 128)            0         ['dropout_9[0][0]',
#  OpLambda)                                                           'layer_normalization_8[0][0]'
#                                                                     ]
#
#  layer_normalization_9 (Lay  (None, 6934, 128)            256       ['tf.__operators__.add_9[0][0]
#  erNormalization)                                                   ']
#
#  multi_head_attention_5 (Mu  (None, 6934, 128)            527488    ['layer_normalization_9[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_9[0][0]
#                                                                     ']
#
#  dropout_10 (Dropout)        (None, 6934, 128)            0         ['multi_head_attention_5[0][0]
#                                                                     ']
#
#  tf.__operators__.add_10 (T  (None, 6934, 128)            0         ['dropout_10[0][0]',
#  FOpLambda)                                                          'layer_normalization_9[0][0]'
#                                                                     ]
#
#  layer_normalization_10 (La  (None, 6934, 128)            256       ['tf.__operators__.add_10[0][0
#  yerNormalization)                                                  ]']
#
#  dense_12 (Dense)            (None, 6934, 512)            66048     ['layer_normalization_10[0][0]
#                                                                     ']
#
#  dense_13 (Dense)            (None, 6934, 128)            65664     ['dense_12[0][0]']
#
#  dropout_11 (Dropout)        (None, 6934, 128)            0         ['dense_13[0][0]']
#
#  tf.__operators__.add_11 (T  (None, 6934, 128)            0         ['dropout_11[0][0]',
#  FOpLambda)                                                          'layer_normalization_10[0][0]
#                                                                     ']
#
#  layer_normalization_11 (La  (None, 6934, 128)            256       ['tf.__operators__.add_11[0][0
#  yerNormalization)                                                  ]']
#
#  multi_head_attention_6 (Mu  (None, 6934, 128)            527488    ['layer_normalization_11[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_11[0][0]
#                                                                     ']
#
#  dropout_12 (Dropout)        (None, 6934, 128)            0         ['multi_head_attention_6[0][0]
#                                                                     ']
#
#  tf.__operators__.add_12 (T  (None, 6934, 128)            0         ['dropout_12[0][0]',
#  FOpLambda)                                                          'layer_normalization_11[0][0]
#                                                                     ']
#
#  layer_normalization_12 (La  (None, 6934, 128)            256       ['tf.__operators__.add_12[0][0
#  yerNormalization)                                                  ]']
#
#  dense_14 (Dense)            (None, 6934, 512)            66048     ['layer_normalization_12[0][0]
#                                                                     ']
#
#  dense_15 (Dense)            (None, 6934, 128)            65664     ['dense_14[0][0]']
#
#  dropout_13 (Dropout)        (None, 6934, 128)            0         ['dense_15[0][0]']
#
#  tf.__operators__.add_13 (T  (None, 6934, 128)            0         ['dropout_13[0][0]',
#  FOpLambda)                                                          'layer_normalization_12[0][0]
#                                                                     ']
#
#  layer_normalization_13 (La  (None, 6934, 128)            256       ['tf.__operators__.add_13[0][0
#  yerNormalization)                                                  ]']
#
#  multi_head_attention_7 (Mu  (None, 6934, 128)            527488    ['layer_normalization_13[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_13[0][0]
#                                                                     ']
#
#  dropout_14 (Dropout)        (None, 6934, 128)            0         ['multi_head_attention_7[0][0]
#                                                                     ']
#
#  tf.__operators__.add_14 (T  (None, 6934, 128)            0         ['dropout_14[0][0]',
#  FOpLambda)                                                          'layer_normalization_13[0][0]
#                                                                     ']
#
#  layer_normalization_14 (La  (None, 6934, 128)            256       ['tf.__operators__.add_14[0][0
#  yerNormalization)                                                  ]']
#
#  dense_16 (Dense)            (None, 6934, 512)            66048     ['layer_normalization_14[0][0]
#                                                                     ']
#
#  dense_17 (Dense)            (None, 6934, 128)            65664     ['dense_16[0][0]']
#
#  dropout_15 (Dropout)        (None, 6934, 128)            0         ['dense_17[0][0]']
#
#  tf.__operators__.add_15 (T  (None, 6934, 128)            0         ['dropout_15[0][0]',
#  FOpLambda)                                                          'layer_normalization_14[0][0]
#                                                                     ']
#
#  layer_normalization_15 (La  (None, 6934, 128)            256       ['tf.__operators__.add_15[0][0
#  yerNormalization)                                                  ]']
#
#  time_distributed_2 (TimeDi  (None, 6934, 512)            66048     ['layer_normalization_15[0][0]
#  stributed)                                                         ']
#
#  time_distributed_3 (TimeDi  (None, 6934, 28)             14364     ['time_distributed_2[0][0]']
#  stributed)
#
# ==================================================================================================
# Total params: 2811932 (10.73 MB)
# Trainable params: 2811932 (10.73 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.utils import class_weight
import numpy as np


""" In case want to calculate class weights here instead of above
y_train_flat = np.argmax(y_train_one_hot, axis=-1).flatten()

# Calculate class weights
class_weights = class_weight.compute_class_weight(class_weight='balanced', classes=np.unique(y_train_flat), y=y_train_flat)

# Convert to a dictionary format to easily map class indices to their weights
class_weights_dict = dict(enumerate(class_weights))
"""


# Set up ModelCheckpoint with min_delta
checkpoint = ModelCheckpoint(
    'focalLossAttempt1.h5',
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    min_delta=0.001  # Only save the model if the validation loss decreases by at least 0.001
)

# Set up EarlyStopping with min_delta
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=5,
    mode='min',
    min_delta=0.001,  # Stop training if the validation loss does not decrease by at least 0.001
    restore_best_weights=True
)


model.compile(optimizer='adam', loss=loss_fn, metrics=['accuracy'])

# Train the model, let's experiment w/higher epochs & batche sizes soon
history = model.fit(
    X_train,
    y_train_one_hot,
    validation_data=(X_test, y_test_one_hot),  # Use validation data to monitor training
    epochs=50,  #Make sure to note accuracy changes w/epoch increases
    batch_size=8,  # Adjust batch size based on your GPU/CPU memory
    callbacks=[checkpoint, early_stopping],  # Use callbacks for better training
    verbose=1,  # Print training progress
    class_weight=class_weights_dict
)

# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(X_test, y_test_one_hot)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")

# Save the trained model
model.save('focalLossAttempt1.h5.h5')
# Out:
# Epoch 1/50
# 36/36 [==============================] - ETA: 0s - loss: 2.9014 - accuracy: 0.0108
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 36/36 [==============================] - 2385s 66s/step - loss: 2.9014 - accuracy: 0.0108 - val_loss: 2.8630 - val_accuracy: 0.0039
# Epoch 2/50
# 36/36 [==============================] - 2394s 67s/step - loss: 2.7199 - accuracy: 0.0483 - val_loss: 3.2929 - val_accuracy: 0.0025
# Epoch 3/50
# 36/36 [==============================] - 2397s 67s/step - loss: 2.6542 - accuracy: 0.0032 - val_loss: 2.6871 - val_accuracy: 0.0162
# Epoch 4/50
# 36/36 [==============================] - 2409s 67s/step - loss: 2.6891 - accuracy: 0.0253 - val_loss: 2.8671 - val_accuracy: 7.5914e-04
# Epoch 5/50
# 36/36 [==============================] - 2416s 67s/step - loss: 2.6854 - accuracy: 0.0386 - val_loss: 3.0932 - val_accuracy: 0.0012
# Epoch 6/50
# 36/36 [==============================] - 2417s 67s/step - loss: 2.9366 - accuracy: 0.0589 - val_loss: 2.9057 - val_accuracy: 0.1938
# Epoch 7/50
# 36/36 [==============================] - 2425s 68s/step - loss: 2.9156 - accuracy: 0.0816 - val_loss: 2.9672 - val_accuracy: 4.7672e-04
# Epoch 8/50
# 36/36 [==============================] - 2440s 68s/step - loss: 2.9062 - accuracy: 0.0012 - val_loss: 3.0544 - val_accuracy: 0.0013
# 3/3 [==============================] - 257s 71s/step - loss: 2.6871 - accuracy: 0.0162
# Test Loss: 2.687126398086548
# Test Accuracy: 0.016234416514635086
